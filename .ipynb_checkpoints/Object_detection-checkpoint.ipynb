# %% [markdown]
# # Object Detection
# This notebook trains convolutional object detection models on a 2x3 grid setup, selects the best model on validation performance, and evaluates it on the test set.

# %% [markdown]
# ## 1) Imports and runtime setup
# This cell imports all required libraries, sets a random seed, and picks CPU or GPU automatically.

# %%
import itertools
import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import TensorDataset
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from torchmetrics.detection.mean_ap import MeanAveragePrecision
import numpy as np
import seaborn as sns
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    precision_recall_fscore_support,
)
print(f"Seaborn Version version: {sns.__version__}")


SEED = 123
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on device: {device}")
# Out:
# Seaborn Version version: 0.13.2
# Training on device: cuda

# %% [markdown]
# ## 2) Configuration
# This cell defines image size, output grid size, number of classes, and the model variants that will be compared.

# %%
H_IN, W_IN = 48, 60
H_OUT, W_OUT = 2, 3
NUM_CLASSES = 2
OUT_CHANNELS = NUM_CLASSES + 5

model_configs = {
    'small': {'channels': (16, 32), 'head_channels': 64, 'dropout': 0.10},
    'base': {'channels': (16, 32, 64), 'head_channels': 128, 'dropout': 0.10},
    'deep': {'channels': (16, 32, 64, 96), 'head_channels': 160, 'dropout': 0.15},
}


def seed_everything(SEED):
    torch.manual_seed(SEED)
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
seed_everything(SEED)

# %% [markdown]
# ## 3) Detection model
# This is a fully convolutional detector that outputs `(N, C+5, H_OUT, W_OUT)` where each cell predicts objectness, bounding box, and class logits.

# %%
class DetectionCNN(nn.Module):
    def __init__(self, channels=(16, 32, 64), head_channels=128, dropout=0.10, num_classes=NUM_CLASSES):
        super().__init__()

        blocks = []
        in_channels = 1
        for out_channels in channels:
            blocks.extend([
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(2),
            ])
            in_channels = out_channels

        self.backbone = nn.Sequential(*blocks)
        self.grid_pool = nn.AdaptiveAvgPool2d((H_OUT, W_OUT))
        self.head = nn.Sequential(
            nn.Conv2d(in_channels, head_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Dropout2d(dropout),
            nn.Conv2d(head_channels, num_classes + 5, kernel_size=1),
        )

    def forward(self, x):
        x = self.backbone(x)
        x = self.grid_pool(x)
        return self.head(x)

# %% [markdown]
# ## 4) Loss and geometric helpers
# This cell defines the detection loss (objectness + bounding box + class) and utility functions for IoU and coordinate conversion.

# %%
def _mean_or_zero(values, device):
    return values.mean() if values.numel() > 0 else torch.tensor(0.0, device=device)


def detection_loss(y_pred, y_true, lambda_noobj=0.25, lambda_bbox=2.0, lambda_cls=1.0):
    """
    y_pred: (N, C+5, H_OUT, W_OUT)
    y_true: (N, H_OUT, W_OUT, 6)
    """
    y_pred = y_pred.permute(0, 2, 3, 1)

    true_object = y_true[..., 0].float()
    pred_object_logits = y_pred[..., 0]

    bce = F.binary_cross_entropy_with_logits(pred_object_logits, true_object, reduction='none')
    object_mask = true_object > 0.5
    no_object_mask = ~object_mask

    object_loss = _mean_or_zero(bce[object_mask], y_pred.device)
    no_object_loss = _mean_or_zero(bce[no_object_mask], y_pred.device)
    detection_term = object_loss + lambda_noobj * no_object_loss

    pred_xy = torch.sigmoid(y_pred[..., 1:3])
    pred_wh = F.softplus(y_pred[..., 3:5])
    pred_bbox = torch.cat([pred_xy, pred_wh], dim=-1)
    true_bbox = y_true[..., 1:5].float()

    bbox_term = _mean_or_zero(
        F.smooth_l1_loss(pred_bbox[object_mask], true_bbox[object_mask], reduction='none').mean(dim=-1),
        y_pred.device,
    )

    class_logits = y_pred[..., 5:]
    class_targets = y_true[..., 5].long().clamp(min=0, max=NUM_CLASSES - 1)
    class_term = _mean_or_zero(
        F.cross_entropy(class_logits[object_mask], class_targets[object_mask], reduction='none'),
        y_pred.device,
    )

    return detection_term + lambda_bbox * bbox_term + lambda_cls * class_term


def xywh_iou(box1, box2):
    """
    box1, box2: (..., 4), format [x_center, y_center, width, height]
    """
    box1_min = box1[..., :2] - 0.5 * box1[..., 2:]
    box1_max = box1[..., :2] + 0.5 * box1[..., 2:]
    box2_min = box2[..., :2] - 0.5 * box2[..., 2:]
    box2_max = box2[..., :2] + 0.5 * box2[..., 2:]

    inter_min = torch.maximum(box1_min, box2_min)
    inter_max = torch.minimum(box1_max, box2_max)
    inter_wh = (inter_max - inter_min).clamp(min=0)
    inter_area = inter_wh[..., 0] * inter_wh[..., 1]

    area1 = (box1[..., 2] * box1[..., 3]).clamp(min=0)
    area2 = (box2[..., 2] * box2[..., 3]).clamp(min=0)
    union = area1 + area2 - inter_area

    return torch.where(union > 0, inter_area / union, torch.zeros_like(union))


def local_to_global(row, col, local_box):
    x, y, w, h = local_box
    cell_w = 1.0 / W_OUT
    cell_h = 1.0 / H_OUT
    global_x = (col + x) * cell_w
    global_y = (row + y) * cell_h
    global_w = w * cell_w
    global_h = h * cell_h
    return global_x, global_y, global_w, global_h


def xywh_to_xyxy(box):
    x, y, w, h = box
    x1 = x - 0.5 * w
    y1 = y - 0.5 * h
    x2 = x + 0.5 * w
    y2 = y + 0.5 * h
    return x1, y1, x2, y2

# %% [markdown]
# ## 5) Load Images And Build Detection Targets
# This section implements task 3.1.1 by loading the raw `list_y_true_*.pt` annotations, filtering to the two detection classes, assigning each object to a `2 x 3` grid cell, and converting global bounding boxes to local cell coordinates. The local files do not contain separate image-only tensors, so the split image tensors are reused while the detection targets are rebuilt from scratch.

# %%
data_path = '../data_2/'


def safe_load(path):
    try:
        return torch.load(path, map_location='cpu', weights_only=False)
    except TypeError:
        return torch.load(path, map_location='cpu')


def filter_detection_classes(raw_boxes, allowed_classes=None):
    if allowed_classes is None:
        allowed_classes = tuple(range(NUM_CLASSES))

    filtered_boxes = []
    for box in raw_boxes:
        box_tensor = box.clone().float()
        if int(box_tensor[5].item()) in allowed_classes:
            filtered_boxes.append(box_tensor)
    return filtered_boxes


def convert_boxes_to_grid(raw_boxes, h_out, w_out):
    target_grid = torch.zeros(h_out, w_out, 6, dtype=torch.float32)

    for box in raw_boxes:
        box_tensor = box.float()
        pc = box_tensor[0]
        x_center = box_tensor[1]
        y_center = box_tensor[2]
        box_w = box_tensor[3]
        box_h = box_tensor[4]
        class_id = box_tensor[5]

        if pc.item() <= 0:
            continue

        col = min(int((x_center * w_out).item()), w_out - 1)
        row = min(int((y_center * h_out).item()), h_out - 1)

        if target_grid[row, col, 0] > 0.5:
            raise ValueError(
                f'Multiple objects mapped to cell {(row, col)} for a {h_out}x{w_out} grid.'
            )

        target_grid[row, col, 0] = pc
        target_grid[row, col, 1] = x_center * w_out - col
        target_grid[row, col, 2] = y_center * h_out - row
        target_grid[row, col, 3] = box_w * w_out
        target_grid[row, col, 4] = box_h * h_out
        target_grid[row, col, 5] = class_id

    return target_grid


def build_detection_dataset(image_source, raw_annotation_source, split_name):
    images = image_source.tensors[0].float().clone()

    if len(images) != len(raw_annotation_source):
        raise ValueError(
            f'{split_name} split has {len(images)} images but {len(raw_annotation_source)} raw annotations.'
        )

    targets = torch.zeros(len(images), H_OUT, W_OUT, 6, dtype=torch.float32)
    for index, raw_boxes in enumerate(raw_annotation_source):
        filtered_boxes = filter_detection_classes(raw_boxes)
        targets[index] = convert_boxes_to_grid(filtered_boxes, H_OUT, W_OUT)

    print(f'{split_name}: {len(images)} images | targets shape={tuple(targets.shape)}')
    return TensorDataset(images, targets)


# The raw annotation files only contain y_true lists, so the split tensor datasets are
# reused strictly as image sources while all detection targets are reconstructed here.
train_image_source = safe_load(f"{data_path}detection_train.pt")
val_image_source = safe_load(f"{data_path}detection_val.pt")
test_image_source = safe_load(f"{data_path}detection_test.pt")

train_raw_targets = safe_load(f"{data_path}list_y_true_train.pt")
val_raw_targets = safe_load(f"{data_path}list_y_true_val.pt")
test_raw_targets = safe_load(f"{data_path}list_y_true_test.pt")

train_data = build_detection_dataset(train_image_source, train_raw_targets, 'Train')
val_data = build_detection_dataset(val_image_source, val_raw_targets, 'Validation')
test_data = build_detection_dataset(test_image_source, test_raw_targets, 'Test')
# Out:
# Train: 26874 images | targets shape=(26874, 2, 3, 6)
# Validation: 2967 images | targets shape=(2967, 2, 3, 6)
# Test: 4981 images | targets shape=(4981, 2, 3, 6)

# %% [markdown]
# ## 6) Exploratory Data Analysis
# This section checks class balance, summarizes each split, and visualizes a few annotated test samples before normalization and training.

# %%
# Collect per-split class counts and a few summary statistics.
eda_class_names = [f"Class {class_idx}" for class_idx in range(NUM_CLASSES)]
detection_splits = {
    "Train": train_data,
    "Validation": val_data,
    "Test": test_data,
}


def _eda_extract_detection_annotations(target_grid):
    target_grid = target_grid.float()
    annotations = []
    for row in range(H_OUT):
        for col in range(W_OUT):
            cell = target_grid[row, col]
            if cell[0] <= 0.5:
                continue
            annotations.append({
                "label": int(cell[5].item()),
                "bbox": local_to_global(row, col, cell[1:5]),
            })
    return annotations


split_class_counts = {}
split_metadata = {}

for split_name, dataset in detection_splits.items():
    class_counts = torch.zeros(NUM_CLASSES, dtype=torch.long)
    objects_per_image = []

    for _, target in dataset:
        annotations = _eda_extract_detection_annotations(target)
        objects_per_image.append(len(annotations))
        for annotation in annotations:
            class_counts[annotation["label"]] += 1

    split_class_counts[split_name] = class_counts
    split_metadata[split_name] = {
        "samples": len(dataset),
        "object_instances": int(class_counts.sum().item()),
        "images_with_objects": sum(count > 0 for count in objects_per_image),
        "avg_objects_per_image": sum(objects_per_image) / len(objects_per_image),
        "max_objects_in_image": max(objects_per_image) if objects_per_image else 0,
    }

overall_class_counts = torch.stack(list(split_class_counts.values())).sum(dim=0)
sample_image, sample_target = train_data[0]

print("Dataset summary")
print(f"Image size: {tuple(sample_image.shape[-2:])} | Grid size: {(H_OUT, W_OUT)} | Number of classes: {NUM_CLASSES}")
print(
    f"Target format: [objectness, x_center, y_center, width, height, class_id] per grid cell | "
    f"target grid shape: {tuple(sample_target.shape)}"
)
for split_name, metadata in split_metadata.items():
    print(
        f"{split_name}: {metadata['samples']} samples | "
        f"{metadata['object_instances']} object instances | "
        f"{metadata['images_with_objects']} images with objects | "
        f"avg objects/image: {metadata['avg_objects_per_image']:.2f} | "
        f"max objects/image: {metadata['max_objects_in_image']}"
    )
print(
    "Overall class counts: "
    + ", ".join(
        f"{class_name}={int(count)}"
        for class_name, count in zip(eda_class_names, overall_class_counts.tolist())
    )
)

# Visualize how the class distribution changes across splits.
class_positions = torch.arange(NUM_CLASSES, dtype=torch.float32)
bar_width = 0.25
split_colors = {
    "Train": "#4C78A8",
    "Validation": "#F58518",
    "Test": "#54A24B",
}

fig, ax = plt.subplots(figsize=(8, 4.5))
for offset, (split_name, counts) in enumerate(split_class_counts.items()):
    shift = (offset - (len(split_class_counts) - 1) / 2) * bar_width
    ax.bar(
        (class_positions + shift).tolist(),
        counts.tolist(),
        width=bar_width,
        label=split_name,
        color=split_colors[split_name],
    )

ax.set_title("Detection class distribution by split")
ax.set_xlabel("Class label")
ax.set_ylabel("Object instances")
ax.set_xticks(class_positions.tolist())
ax.set_xticklabels(eda_class_names)
ax.legend()
ax.grid(axis="y", linestyle="--", alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Dataset summary
# Image size: (48, 60) | Grid size: (2, 3) | Number of classes: 2
# Target format: [objectness, x_center, y_center, width, height, class_id] per grid cell | target grid shape: (2, 3, 6)
# Train: 26874 samples | 34260 object instances | 26874 images with objects | avg objects/image: 1.27 | max objects/image: 4
# Validation: 2967 samples | 3735 object instances | 2967 images with objects | avg objects/image: 1.26 | max objects/image: 3
# Test: 4981 samples | 6345 object instances | 4981 images with objects | avg objects/image: 1.27 | max objects/image: 4
# Overall class counts: Class 0=20709, Class 1=23631

# %%
# Plot a small, evenly spaced subset of the test set with ground-truth boxes and labels.
num_samples = min(6, len(test_data))
sample_indices = torch.linspace(0, len(test_data) - 1, steps=num_samples).long().tolist()
num_cols = min(3, num_samples)
num_rows = (num_samples + num_cols - 1) // num_cols

fig, axes = plt.subplots(num_rows, num_cols, figsize=(4.5 * num_cols, 3.8 * num_rows))
if hasattr(axes, "ravel"):
    axes = axes.ravel()
else:
    axes = [axes]

for ax, sample_idx in zip(axes, sample_indices):
    image, target = test_data[int(sample_idx)]
    image = image.float()
    if image.ndim == 3:
        image = image.squeeze(0)

    ax.imshow(image, cmap="gray")
    annotations = _eda_extract_detection_annotations(target)
    label_names = []

    for annotation in annotations:
        x_center, y_center, box_w, box_h = annotation["bbox"]
        left = (x_center - 0.5 * box_w) * W_IN
        top = (y_center - 0.5 * box_h) * H_IN
        width = box_w * W_IN
        height = box_h * H_IN
        label_name = eda_class_names[annotation["label"]]
        label_names.append(label_name)

        ax.add_patch(
            patches.Rectangle((left, top), width, height, fill=False, edgecolor="lime", linewidth=2)
        )
        ax.text(
            left,
            max(top - 1, 0),
            label_name,
            fontsize=8,
            color="black",
            bbox=dict(facecolor="lime", alpha=0.75, pad=1.5),
        )

    label_summary = ", ".join(label_names) if label_names else "None"
    ax.set_title(f"Test sample {sample_idx}\nLabels: {label_summary}", fontsize=9)
    ax.axis("off")

for ax in axes[len(sample_indices):]:
    ax.axis("off")

plt.suptitle("Annotated samples from the detection test set", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7) Normalization and DataLoaders
# This cell computes normalization statistics from the training set and creates dataset wrappers and dataloaders.

# %%
def ensure_channel_first(image):
    image = image.float()
    if image.ndim == 2:
        image = image.unsqueeze(0)
    return image


train_images = torch.stack([ensure_channel_first(image) for image, _ in train_data], dim=0)
train_mean = train_images.mean()
train_std = train_images.std().clamp_min(1e-6)
print(f"Train mean: {train_mean.item():.4f}, train std: {train_std.item():.4f}")


def preprocessor(image):
    return (image - train_mean) / train_std


class DetectionDataset(Dataset):
    def __init__(self, data, preprocessor=None):
        self.data = data
        self.preprocessor = preprocessor

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        image, target = self.data[index]
        image = ensure_channel_first(image)
        target = target.float()
        if self.preprocessor is not None:
            image = self.preprocessor(image)
        return image, target

g = torch.Generator().manual_seed(SEED)
batch_size = 128
train_loader = DataLoader(DetectionDataset(train_data, preprocessor), batch_size=batch_size, shuffle=True, generator=g)
val_loader = DataLoader(DetectionDataset(val_data, preprocessor), batch_size=batch_size, shuffle=False)
test_loader = DataLoader(DetectionDataset(test_data, preprocessor), batch_size=batch_size, shuffle=False)
# Out:
# Train mean: 0.2989, train std: 0.1967

# %%
# Helper used during tuning and final evaluation. 
def get_map_results(model, eval_loader, device):
    model.eval()
    predictions_list = []
    targets_list = []

    with torch.no_grad():
        for images, targets in eval_loader:
            images = images.to(device)
            targets = targets.to(device)
            outputs = model(images).permute(0, 2, 3, 1)

            batch_size = images.shape[0]
            for batch_index in range(batch_size):
                output_grid = outputs[batch_index]
                target_grid = targets[batch_index]

                pred_boxes = []
                pred_scores = []
                pred_labels = []
                true_boxes = []
                true_labels = []

                for row in range(H_OUT):
                    for col in range(W_OUT):
                        pred_cell = output_grid[row, col]
                        target_cell = target_grid[row, col]

                        pred_object = torch.sigmoid(pred_cell[0])
                        if pred_object > 0.5:
                            px = torch.sigmoid(pred_cell[1])
                            py = torch.sigmoid(pred_cell[2])
                            pw = F.softplus(pred_cell[3])
                            ph = F.softplus(pred_cell[4])

                            class_probs = F.softmax(pred_cell[5:], dim=0)
                            pred_label = torch.argmax(class_probs)
                            score = pred_object * class_probs[pred_label]

                            global_box = local_to_global(
                                row, col, torch.stack([px, py, pw, ph])
                            )
                            pred_xyxy = torch.stack(xywh_to_xyxy(global_box))

                            pred_boxes.append(pred_xyxy)
                            pred_scores.append(score)
                            pred_labels.append(pred_label)

                        if target_cell[0] > 0.5:
                            global_box = local_to_global(row, col, target_cell[1:5])
                            true_xyxy = torch.stack(xywh_to_xyxy(global_box))
                            true_boxes.append(true_xyxy)
                            true_labels.append(target_cell[5].long())

                if len(pred_boxes) == 0:
                    pred_dict = {
                        "boxes": torch.zeros((0, 4), device=device),
                        "scores": torch.zeros((0,), device=device),
                        "labels": torch.zeros((0,), dtype=torch.long, device=device),
                    }
                else:
                    pred_dict = {
                        "boxes": torch.stack(pred_boxes),
                        "scores": torch.stack(pred_scores).float(),
                        "labels": torch.stack(pred_labels).long(),
                    }
                predictions_list.append(pred_dict)

                if len(true_boxes) == 0:
                    target_dict = {
                        "boxes": torch.zeros((0, 4), device=device),
                        "labels": torch.zeros((0,), dtype=torch.long, device=device),
                    }
                else:
                    target_dict = {
                        "boxes": torch.stack(true_boxes),
                        "labels": torch.stack(true_labels).long(),
                    }
                targets_list.append(target_dict)

    metric = MeanAveragePrecision(iou_type="bbox")
    metric.update(predictions_list, targets_list)
    return metric.compute()

# %% [markdown]
# ## 8) Training helper
# This function trains one model variant, keeps the best checkpoint by validation mAP@0.5, and logs epoch time.

# %%
def train_single_model(model, train_loader, val_loader, num_epochs=30, learning_rate=1e-3, weight_decay=1e-4):
    optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    history = {
        'train_loss': [],
        'val_loss': [],
        'val_map50': [],
        'epoch_time_sec': [],
    }

    best_val_map50 = float('-inf')
    best_state = None
    training_start = time.perf_counter()

    for epoch in range(num_epochs):
        epoch_start = time.perf_counter()

        model.train()
        train_loss_sum = 0.0
        for images, targets in train_loader:
            images = images.to(device)
            targets = targets.to(device)

            optimizer.zero_grad()
            predictions = model(images)
            loss = detection_loss(predictions, targets)
            loss.backward()
            optimizer.step()

            train_loss_sum += loss.item() * images.size(0)

        train_loss = train_loss_sum / len(train_loader.dataset)

        model.eval()
        val_loss_sum = 0.0
        with torch.no_grad():
            for images, targets in val_loader:
                images = images.to(device)
                targets = targets.to(device)
                predictions = model(images)
                loss = detection_loss(predictions, targets)
                val_loss_sum += loss.item() * images.size(0)

        val_loss = val_loss_sum / len(val_loader.dataset)
        scheduler.step()
        
        map_results = get_map_results(model, val_loader, device)
        val_map50 = float(map_results['map_50'].item())
        if val_map50 > best_val_map50:
            best_val_map50 = val_map50
            best_state = {name: tensor.detach().cpu().clone() for name, tensor in model.state_dict().items()}

        epoch_time = time.perf_counter() - epoch_start
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['val_map50'].append(val_map50)
        history['epoch_time_sec'].append(epoch_time)

        print(
            f"Epoch {epoch + 1:02d}/{num_epochs} | "
            f"train loss: {train_loss:.4f} | val loss: {val_loss:.4f} | val mAP@0.5: {val_map50:.4f} | "
            f"time: {epoch_time:.2f}s"
        )

    history['total_time_sec'] = time.perf_counter() - training_start

    if best_state is not None:
        model.load_state_dict(best_state)

    print(f"Best validation mAP@0.5: {best_val_map50:.4f}")
    print(f"Total training time: {history['total_time_sec']:.2f}s")
    return model, history

# %% [markdown]
# ## 9) Hyperparameter tuning
#
# This cell runs a simple grid search with `itertools`, trains one model per configuration, evaluates each model with `get_map_results()`, and keeps the best run by validation mAP@0.5.

# %%
hyperparameter_space = {
    'model_name': ['small', 'base', 'deep'],
    'learning_rate': [1e-3, 5e-4],
    'weight_decay': [1e-3, 1e-4],
    'num_epochs': [20],
}

keys = list(hyperparameter_space.keys())
all_combinations = list(itertools.product(*(hyperparameter_space[key] for key in keys)))

trained_models = {}
training_histories = {}
tuning_results = []

best_map50 = float('-inf')
best_hyperparameters = None
best_model_name = None
best_model = None

print(f"Total combinations: {len(all_combinations)}")

for run_index, values in enumerate(all_combinations, start=1):
    current_hparams = dict(zip(keys, values))
    run_name = f"run_{run_index:02d}"

    print(f"\n[{run_index}/{len(all_combinations)}] {run_name}: {current_hparams}")

    model_config = model_configs[current_hparams['model_name']]
    seed_everything(SEED)
    current_model = DetectionCNN(**model_config).to(device)

    current_model, history = train_single_model(
        current_model,
        train_loader,
        val_loader,
        num_epochs=current_hparams['num_epochs'],
        learning_rate=current_hparams['learning_rate'],
        weight_decay=current_hparams['weight_decay'],
    )

    map_results = get_map_results(current_model, val_loader, device)
    val_map50 = float(map_results['map_50'].item())

    trained_models[run_name] = current_model
    training_histories[run_name] = history
    tuning_results.append({
        'run_name': run_name,
        **current_hparams,
        'val_map50': val_map50,
    })

    print(f"{run_name} validation mAP@0.5: {val_map50:.4f}")

    if val_map50 > best_map50:
        best_map50 = val_map50
        best_hyperparameters = current_hparams.copy()
        best_model_name = run_name
        best_model = current_model

if best_model is None:
    raise RuntimeError('No model was trained during hyperparameter tuning.')

model = best_model

print("\nBest hyperparameters (by validation mAP@0.5):")
print(best_hyperparameters)
print(f"Best run: {best_model_name}")
print(f"Best validation mAP@0.5: {best_map50:.4f}")
# Out:
# Total combinations: 12
#
# [1/12] run_01: {'model_name': 'small', 'learning_rate': 0.001, 'weight_decay': 0.001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.6546 | val loss: 0.3827 | val mAP@0.5: 0.2076 | time: 10.86s
# Epoch 02/20 | train loss: 0.3546 | val loss: 0.2977 | val mAP@0.5: 0.2879 | time: 9.86s
# Epoch 03/20 | train loss: 0.2950 | val loss: 0.2759 | val mAP@0.5: 0.3126 | time: 10.04s
# Epoch 04/20 | train loss: 0.2562 | val loss: 0.2302 | val mAP@0.5: 0.3427 | time: 10.94s
# Epoch 05/20 | train loss: 0.2278 | val loss: 0.3324 | val mAP@0.5: 0.3469 | time: 9.92s
# Epoch 06/20 | train loss: 0.2087 | val loss: 0.1938 | val mAP@0.5: 0.4432 | time: 10.32s
# Epoch 07/20 | train loss: 0.1910 | val loss: 0.1737 | val mAP@0.5: 0.4697 | time: 11.84s
# Epoch 08/20 | train loss: 0.1777 | val loss: 0.1718 | val mAP@0.5: 0.4660 | time: 11.77s
# Epoch 09/20 | train loss: 0.1665 | val loss: 0.1580 | val mAP@0.5: 0.5254 | time: 10.42s
# Epoch 10/20 | train loss: 0.1587 | val loss: 0.1493 | val mAP@0.5: 0.5368 | time: 10.82s
# Epoch 11/20 | train loss: 0.1516 | val loss: 0.1581 | val mAP@0.5: 0.5420 | time: 10.95s
# Epoch 12/20 | train loss: 0.1460 | val loss: 0.1399 | val mAP@0.5: 0.5740 | time: 11.42s
# Epoch 13/20 | train loss: 0.1416 | val loss: 0.1495 | val mAP@0.5: 0.5484 | time: 11.34s
# Epoch 14/20 | train loss: 0.1380 | val loss: 0.1346 | val mAP@0.5: 0.5829 | time: 11.83s
# Epoch 15/20 | train loss: 0.1342 | val loss: 0.1319 | val mAP@0.5: 0.5822 | time: 9.51s
# Epoch 16/20 | train loss: 0.1326 | val loss: 0.1303 | val mAP@0.5: 0.5924 | time: 10.76s
# Epoch 17/20 | train loss: 0.1300 | val loss: 0.1311 | val mAP@0.5: 0.5930 | time: 10.99s
# Epoch 18/20 | train loss: 0.1294 | val loss: 0.1293 | val mAP@0.5: 0.5920 | time: 9.19s
# Epoch 19/20 | train loss: 0.1285 | val loss: 0.1286 | val mAP@0.5: 0.5903 | time: 11.50s
# Epoch 20/20 | train loss: 0.1278 | val loss: 0.1286 | val mAP@0.5: 0.5913 | time: 10.30s
# Best validation mAP@0.5: 0.5930
# Total training time: 214.62s
# run_01 validation mAP@0.5: 0.5930
#
# [2/12] run_02: {'model_name': 'small', 'learning_rate': 0.001, 'weight_decay': 0.0001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.6523 | val loss: 0.4542 | val mAP@0.5: 0.2052 | time: 11.57s
# Epoch 02/20 | train loss: 0.3563 | val loss: 0.3662 | val mAP@0.5: 0.2710 | time: 10.82s
# Epoch 03/20 | train loss: 0.2914 | val loss: 0.3168 | val mAP@0.5: 0.3356 | time: 10.08s
# Epoch 04/20 | train loss: 0.2546 | val loss: 0.2301 | val mAP@0.5: 0.3692 | time: 10.75s
# Epoch 05/20 | train loss: 0.2310 | val loss: 0.2448 | val mAP@0.5: 0.4014 | time: 11.11s
# Epoch 06/20 | train loss: 0.2095 | val loss: 0.1904 | val mAP@0.5: 0.4507 | time: 11.91s
# Epoch 07/20 | train loss: 0.1940 | val loss: 0.1964 | val mAP@0.5: 0.4884 | time: 10.71s
# Epoch 08/20 | train loss: 0.1813 | val loss: 0.1768 | val mAP@0.5: 0.4473 | time: 10.85s
# Epoch 09/20 | train loss: 0.1695 | val loss: 0.1595 | val mAP@0.5: 0.5241 | time: 11.90s
# Epoch 10/20 | train loss: 0.1617 | val loss: 0.1581 | val mAP@0.5: 0.5173 | time: 10.75s
# Epoch 11/20 | train loss: 0.1563 | val loss: 0.1581 | val mAP@0.5: 0.5389 | time: 9.94s
# Epoch 12/20 | train loss: 0.1499 | val loss: 0.1514 | val mAP@0.5: 0.5350 | time: 11.86s
# Epoch 13/20 | train loss: 0.1455 | val loss: 0.1640 | val mAP@0.5: 0.5329 | time: 10.67s
# Epoch 14/20 | train loss: 0.1435 | val loss: 0.1409 | val mAP@0.5: 0.5498 | time: 9.11s
# Epoch 15/20 | train loss: 0.1392 | val loss: 0.1401 | val mAP@0.5: 0.5524 | time: 10.75s
# Epoch 16/20 | train loss: 0.1360 | val loss: 0.1399 | val mAP@0.5: 0.5603 | time: 10.19s
# Epoch 17/20 | train loss: 0.1345 | val loss: 0.1437 | val mAP@0.5: 0.5638 | time: 9.71s
# Epoch 18/20 | train loss: 0.1349 | val loss: 0.1357 | val mAP@0.5: 0.5656 | time: 9.75s
# Epoch 19/20 | train loss: 0.1340 | val loss: 0.1348 | val mAP@0.5: 0.5687 | time: 9.72s
# Epoch 20/20 | train loss: 0.1333 | val loss: 0.1349 | val mAP@0.5: 0.5683 | time: 10.39s
# Best validation mAP@0.5: 0.5687
# Total training time: 212.54s
# run_02 validation mAP@0.5: 0.5687
#
# [3/12] run_03: {'model_name': 'small', 'learning_rate': 0.0005, 'weight_decay': 0.001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.8011 | val loss: 0.4749 | val mAP@0.5: 0.1376 | time: 11.28s
# Epoch 02/20 | train loss: 0.4184 | val loss: 0.3612 | val mAP@0.5: 0.2145 | time: 8.24s
# Epoch 03/20 | train loss: 0.3487 | val loss: 0.3122 | val mAP@0.5: 0.2767 | time: 10.13s
# Epoch 04/20 | train loss: 0.3077 | val loss: 0.2764 | val mAP@0.5: 0.3169 | time: 10.70s
# Epoch 05/20 | train loss: 0.2815 | val loss: 0.2722 | val mAP@0.5: 0.3345 | time: 10.87s
# Epoch 06/20 | train loss: 0.2584 | val loss: 0.2390 | val mAP@0.5: 0.3508 | time: 11.57s
# Epoch 07/20 | train loss: 0.2426 | val loss: 0.2645 | val mAP@0.5: 0.3510 | time: 11.61s
# Epoch 08/20 | train loss: 0.2307 | val loss: 0.2165 | val mAP@0.5: 0.3812 | time: 11.47s
# Epoch 09/20 | train loss: 0.2186 | val loss: 0.2066 | val mAP@0.5: 0.4008 | time: 7.95s
# Epoch 10/20 | train loss: 0.2103 | val loss: 0.2009 | val mAP@0.5: 0.4045 | time: 8.16s
# Epoch 11/20 | train loss: 0.2033 | val loss: 0.1932 | val mAP@0.5: 0.4189 | time: 10.57s
# Epoch 12/20 | train loss: 0.1976 | val loss: 0.1915 | val mAP@0.5: 0.4219 | time: 10.44s
# Epoch 13/20 | train loss: 0.1936 | val loss: 0.1868 | val mAP@0.5: 0.4170 | time: 10.14s
# Epoch 14/20 | train loss: 0.1893 | val loss: 0.1832 | val mAP@0.5: 0.4260 | time: 10.41s
# Epoch 15/20 | train loss: 0.1875 | val loss: 0.1815 | val mAP@0.5: 0.4357 | time: 12.16s
# Epoch 16/20 | train loss: 0.1837 | val loss: 0.1799 | val mAP@0.5: 0.4445 | time: 11.40s
# Epoch 17/20 | train loss: 0.1809 | val loss: 0.1785 | val mAP@0.5: 0.4434 | time: 9.98s
# Epoch 18/20 | train loss: 0.1806 | val loss: 0.1784 | val mAP@0.5: 0.4446 | time: 9.78s
# Epoch 19/20 | train loss: 0.1806 | val loss: 0.1776 | val mAP@0.5: 0.4462 | time: 10.98s
# Epoch 20/20 | train loss: 0.1798 | val loss: 0.1774 | val mAP@0.5: 0.4469 | time: 11.53s
# Best validation mAP@0.5: 0.4469
# Total training time: 209.36s
# run_03 validation mAP@0.5: 0.4469
#
# [4/12] run_04: {'model_name': 'small', 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.8107 | val loss: 0.4584 | val mAP@0.5: 0.1467 | time: 11.71s
# Epoch 02/20 | train loss: 0.4209 | val loss: 0.3686 | val mAP@0.5: 0.2150 | time: 12.67s
# Epoch 03/20 | train loss: 0.3452 | val loss: 0.2981 | val mAP@0.5: 0.2900 | time: 10.26s
# Epoch 04/20 | train loss: 0.3037 | val loss: 0.2725 | val mAP@0.5: 0.3149 | time: 9.30s
# Epoch 05/20 | train loss: 0.2761 | val loss: 0.2533 | val mAP@0.5: 0.3367 | time: 11.79s
# Epoch 06/20 | train loss: 0.2550 | val loss: 0.2370 | val mAP@0.5: 0.3499 | time: 10.93s
# Epoch 07/20 | train loss: 0.2405 | val loss: 0.2252 | val mAP@0.5: 0.3727 | time: 12.46s
# Epoch 08/20 | train loss: 0.2281 | val loss: 0.2188 | val mAP@0.5: 0.3790 | time: 12.38s
# Epoch 09/20 | train loss: 0.2165 | val loss: 0.2050 | val mAP@0.5: 0.3988 | time: 11.11s
# Epoch 10/20 | train loss: 0.2095 | val loss: 0.1976 | val mAP@0.5: 0.4220 | time: 12.32s
# Epoch 11/20 | train loss: 0.2011 | val loss: 0.1938 | val mAP@0.5: 0.4353 | time: 12.12s
# Epoch 12/20 | train loss: 0.1961 | val loss: 0.1906 | val mAP@0.5: 0.4433 | time: 12.19s
# Epoch 13/20 | train loss: 0.1896 | val loss: 0.1861 | val mAP@0.5: 0.4496 | time: 12.56s
# Epoch 14/20 | train loss: 0.1865 | val loss: 0.1813 | val mAP@0.5: 0.4668 | time: 11.16s
# Epoch 15/20 | train loss: 0.1831 | val loss: 0.1790 | val mAP@0.5: 0.4647 | time: 12.01s
# Epoch 16/20 | train loss: 0.1809 | val loss: 0.1769 | val mAP@0.5: 0.4747 | time: 10.30s
# Epoch 17/20 | train loss: 0.1790 | val loss: 0.1788 | val mAP@0.5: 0.4769 | time: 9.91s
# Epoch 18/20 | train loss: 0.1784 | val loss: 0.1756 | val mAP@0.5: 0.4768 | time: 12.56s
# Epoch 19/20 | train loss: 0.1779 | val loss: 0.1749 | val mAP@0.5: 0.4770 | time: 12.34s
# Epoch 20/20 | train loss: 0.1773 | val loss: 0.1748 | val mAP@0.5: 0.4776 | time: 9.19s
# Best validation mAP@0.5: 0.4776
# Total training time: 229.27s
# run_04 validation mAP@0.5: 0.4776
#
# [5/12] run_05: {'model_name': 'base', 'learning_rate': 0.001, 'weight_decay': 0.001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.4007 | val loss: 0.2185 | val mAP@0.5: 0.5149 | time: 12.63s
# Epoch 02/20 | train loss: 0.1691 | val loss: 0.3680 | val mAP@0.5: 0.5949 | time: 11.73s
# Epoch 03/20 | train loss: 0.1323 | val loss: 0.1206 | val mAP@0.5: 0.6986 | time: 12.68s
# Epoch 04/20 | train loss: 0.1131 | val loss: 0.1296 | val mAP@0.5: 0.7200 | time: 10.79s
# Epoch 05/20 | train loss: 0.0977 | val loss: 0.1002 | val mAP@0.5: 0.7539 | time: 12.40s
# Epoch 06/20 | train loss: 0.0863 | val loss: 0.0901 | val mAP@0.5: 0.7817 | time: 11.71s
# Epoch 07/20 | train loss: 0.0800 | val loss: 0.0881 | val mAP@0.5: 0.8137 | time: 11.91s
# Epoch 08/20 | train loss: 0.0747 | val loss: 0.0902 | val mAP@0.5: 0.7986 | time: 11.08s
# Epoch 09/20 | train loss: 0.0691 | val loss: 0.0848 | val mAP@0.5: 0.8227 | time: 11.50s
# Epoch 10/20 | train loss: 0.0643 | val loss: 0.0777 | val mAP@0.5: 0.8272 | time: 10.99s
# Epoch 11/20 | train loss: 0.0593 | val loss: 0.0760 | val mAP@0.5: 0.8476 | time: 10.30s
# Epoch 12/20 | train loss: 0.0560 | val loss: 0.0754 | val mAP@0.5: 0.8490 | time: 9.92s
# Epoch 13/20 | train loss: 0.0537 | val loss: 0.0957 | val mAP@0.5: 0.8388 | time: 12.26s
# Epoch 14/20 | train loss: 0.0513 | val loss: 0.0771 | val mAP@0.5: 0.8474 | time: 10.56s
# Epoch 15/20 | train loss: 0.0492 | val loss: 0.0783 | val mAP@0.5: 0.8550 | time: 11.20s
# Epoch 16/20 | train loss: 0.0479 | val loss: 0.0773 | val mAP@0.5: 0.8586 | time: 12.25s
# Epoch 17/20 | train loss: 0.0461 | val loss: 0.0765 | val mAP@0.5: 0.8598 | time: 11.32s
# Epoch 18/20 | train loss: 0.0454 | val loss: 0.0759 | val mAP@0.5: 0.8572 | time: 11.64s
# Epoch 19/20 | train loss: 0.0447 | val loss: 0.0732 | val mAP@0.5: 0.8658 | time: 10.93s
# Epoch 20/20 | train loss: 0.0440 | val loss: 0.0740 | val mAP@0.5: 0.8570 | time: 11.81s
# Best validation mAP@0.5: 0.8658
# Total training time: 229.65s
# run_05 validation mAP@0.5: 0.8658
#
# [6/12] run_06: {'model_name': 'base', 'learning_rate': 0.001, 'weight_decay': 0.0001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.3888 | val loss: 0.2643 | val mAP@0.5: 0.5037 | time: 10.30s
# Epoch 02/20 | train loss: 0.1689 | val loss: 0.1807 | val mAP@0.5: 0.6699 | time: 10.31s
# Epoch 03/20 | train loss: 0.1290 | val loss: 0.2016 | val mAP@0.5: 0.7009 | time: 11.50s
# Epoch 04/20 | train loss: 0.1108 | val loss: 0.1010 | val mAP@0.5: 0.7503 | time: 11.30s
# Epoch 05/20 | train loss: 0.0949 | val loss: 0.1255 | val mAP@0.5: 0.7400 | time: 10.55s
# Epoch 06/20 | train loss: 0.0856 | val loss: 0.0968 | val mAP@0.5: 0.8002 | time: 10.05s
# Epoch 07/20 | train loss: 0.0825 | val loss: 0.0882 | val mAP@0.5: 0.7915 | time: 9.26s
# Epoch 08/20 | train loss: 0.0715 | val loss: 0.0866 | val mAP@0.5: 0.8093 | time: 8.94s
# Epoch 09/20 | train loss: 0.0663 | val loss: 0.0807 | val mAP@0.5: 0.8325 | time: 10.75s
# Epoch 10/20 | train loss: 0.0633 | val loss: 0.0973 | val mAP@0.5: 0.8278 | time: 9.31s
# Epoch 11/20 | train loss: 0.0590 | val loss: 0.0790 | val mAP@0.5: 0.8491 | time: 9.94s
# Epoch 12/20 | train loss: 0.0561 | val loss: 0.0764 | val mAP@0.5: 0.8493 | time: 10.92s
# Epoch 13/20 | train loss: 0.0531 | val loss: 0.0745 | val mAP@0.5: 0.8575 | time: 11.28s
# Epoch 14/20 | train loss: 0.0506 | val loss: 0.0803 | val mAP@0.5: 0.8539 | time: 10.61s
# Epoch 15/20 | train loss: 0.0489 | val loss: 0.0808 | val mAP@0.5: 0.8605 | time: 11.39s
# Epoch 16/20 | train loss: 0.0470 | val loss: 0.0740 | val mAP@0.5: 0.8617 | time: 13.20s
# Epoch 17/20 | train loss: 0.0457 | val loss: 0.0781 | val mAP@0.5: 0.8615 | time: 12.06s
# Epoch 18/20 | train loss: 0.0446 | val loss: 0.0783 | val mAP@0.5: 0.8628 | time: 11.95s
# Epoch 19/20 | train loss: 0.0440 | val loss: 0.0756 | val mAP@0.5: 0.8632 | time: 11.91s
# Epoch 20/20 | train loss: 0.0437 | val loss: 0.0770 | val mAP@0.5: 0.8633 | time: 11.19s
# Best validation mAP@0.5: 0.8633
# Total training time: 216.71s
# run_06 validation mAP@0.5: 0.8633
#
# [7/12] run_07: {'model_name': 'base', 'learning_rate': 0.0005, 'weight_decay': 0.001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.4876 | val loss: 0.2593 | val mAP@0.5: 0.4037 | time: 12.18s
# Epoch 02/20 | train loss: 0.2087 | val loss: 0.1659 | val mAP@0.5: 0.6142 | time: 13.20s
# Epoch 03/20 | train loss: 0.1604 | val loss: 0.2350 | val mAP@0.5: 0.6353 | time: 12.20s
# Epoch 04/20 | train loss: 0.1335 | val loss: 0.1373 | val mAP@0.5: 0.7113 | time: 12.90s
# Epoch 05/20 | train loss: 0.1162 | val loss: 0.1157 | val mAP@0.5: 0.7383 | time: 12.82s
# Epoch 06/20 | train loss: 0.1047 | val loss: 0.1284 | val mAP@0.5: 0.7551 | time: 12.18s
# Epoch 07/20 | train loss: 0.0953 | val loss: 0.0987 | val mAP@0.5: 0.7805 | time: 12.39s
# Epoch 08/20 | train loss: 0.0876 | val loss: 0.1368 | val mAP@0.5: 0.7698 | time: 13.26s
# Epoch 09/20 | train loss: 0.0826 | val loss: 0.1160 | val mAP@0.5: 0.7816 | time: 11.54s
# Epoch 10/20 | train loss: 0.0775 | val loss: 0.0915 | val mAP@0.5: 0.8138 | time: 12.00s
# Epoch 11/20 | train loss: 0.0724 | val loss: 0.0940 | val mAP@0.5: 0.8060 | time: 11.59s
# Epoch 12/20 | train loss: 0.0692 | val loss: 0.0872 | val mAP@0.5: 0.8184 | time: 10.84s
# Epoch 13/20 | train loss: 0.0663 | val loss: 0.0892 | val mAP@0.5: 0.8176 | time: 9.81s
# Epoch 14/20 | train loss: 0.0648 | val loss: 0.0885 | val mAP@0.5: 0.8208 | time: 11.26s
# Epoch 15/20 | train loss: 0.0624 | val loss: 0.0910 | val mAP@0.5: 0.8257 | time: 12.34s
# Epoch 16/20 | train loss: 0.0611 | val loss: 0.0884 | val mAP@0.5: 0.8236 | time: 11.25s
# Epoch 17/20 | train loss: 0.0595 | val loss: 0.0845 | val mAP@0.5: 0.8282 | time: 8.65s
# Epoch 18/20 | train loss: 0.0590 | val loss: 0.0858 | val mAP@0.5: 0.8308 | time: 10.88s
# Epoch 19/20 | train loss: 0.0588 | val loss: 0.0854 | val mAP@0.5: 0.8299 | time: 9.45s
# Epoch 20/20 | train loss: 0.0583 | val loss: 0.0857 | val mAP@0.5: 0.8295 | time: 10.66s
# Best validation mAP@0.5: 0.8308
# Total training time: 231.40s
# run_07 validation mAP@0.5: 0.8308
#
# [8/12] run_08: {'model_name': 'base', 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.4832 | val loss: 0.2399 | val mAP@0.5: 0.4165 | time: 11.60s
# Epoch 02/20 | train loss: 0.2033 | val loss: 0.1635 | val mAP@0.5: 0.6036 | time: 11.74s
# Epoch 03/20 | train loss: 0.1577 | val loss: 0.1605 | val mAP@0.5: 0.6664 | time: 9.95s
# Epoch 04/20 | train loss: 0.1305 | val loss: 0.2197 | val mAP@0.5: 0.6971 | time: 11.39s
# Epoch 05/20 | train loss: 0.1146 | val loss: 0.1313 | val mAP@0.5: 0.7463 | time: 12.60s
# Epoch 06/20 | train loss: 0.1035 | val loss: 0.1449 | val mAP@0.5: 0.7780 | time: 9.53s
# Epoch 07/20 | train loss: 0.0935 | val loss: 0.0963 | val mAP@0.5: 0.7933 | time: 11.57s
# Epoch 08/20 | train loss: 0.0865 | val loss: 0.1088 | val mAP@0.5: 0.7762 | time: 12.03s
# Epoch 09/20 | train loss: 0.0808 | val loss: 0.0940 | val mAP@0.5: 0.7976 | time: 11.09s
# Epoch 10/20 | train loss: 0.0759 | val loss: 0.0942 | val mAP@0.5: 0.7949 | time: 11.41s
# Epoch 11/20 | train loss: 0.0724 | val loss: 0.1014 | val mAP@0.5: 0.8145 | time: 11.77s
# Epoch 12/20 | train loss: 0.0685 | val loss: 0.0839 | val mAP@0.5: 0.8036 | time: 12.72s
# Epoch 13/20 | train loss: 0.0653 | val loss: 0.0896 | val mAP@0.5: 0.8250 | time: 13.38s
# Epoch 14/20 | train loss: 0.0633 | val loss: 0.0828 | val mAP@0.5: 0.8316 | time: 12.00s
# Epoch 15/20 | train loss: 0.0608 | val loss: 0.0842 | val mAP@0.5: 0.8314 | time: 11.75s
# Epoch 16/20 | train loss: 0.0597 | val loss: 0.0824 | val mAP@0.5: 0.8354 | time: 11.36s
# Epoch 17/20 | train loss: 0.0588 | val loss: 0.0821 | val mAP@0.5: 0.8396 | time: 12.40s
# Epoch 18/20 | train loss: 0.0578 | val loss: 0.0808 | val mAP@0.5: 0.8399 | time: 10.30s
# Epoch 19/20 | train loss: 0.0573 | val loss: 0.0809 | val mAP@0.5: 0.8396 | time: 11.69s
# Epoch 20/20 | train loss: 0.0568 | val loss: 0.0812 | val mAP@0.5: 0.8405 | time: 9.51s
# Best validation mAP@0.5: 0.8405
# Total training time: 229.79s
# run_08 validation mAP@0.5: 0.8405
#
# [9/12] run_09: {'model_name': 'deep', 'learning_rate': 0.001, 'weight_decay': 0.001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.2543 | val loss: 0.1302 | val mAP@0.5: 0.6745 | time: 10.89s
# Epoch 02/20 | train loss: 0.0933 | val loss: 0.0958 | val mAP@0.5: 0.7648 | time: 9.19s
# Epoch 03/20 | train loss: 0.0721 | val loss: 0.0865 | val mAP@0.5: 0.8215 | time: 11.21s
# Epoch 04/20 | train loss: 0.0596 | val loss: 0.0599 | val mAP@0.5: 0.8699 | time: 13.79s
# Epoch 05/20 | train loss: 0.0515 | val loss: 0.0586 | val mAP@0.5: 0.8689 | time: 10.57s
# Epoch 06/20 | train loss: 0.0444 | val loss: 0.0685 | val mAP@0.5: 0.8994 | time: 12.84s
# Epoch 07/20 | train loss: 0.0423 | val loss: 0.0611 | val mAP@0.5: 0.9105 | time: 13.00s
# Epoch 08/20 | train loss: 0.0353 | val loss: 0.0607 | val mAP@0.5: 0.9154 | time: 11.49s
# Epoch 09/20 | train loss: 0.0301 | val loss: 0.0723 | val mAP@0.5: 0.9081 | time: 11.82s
# Epoch 10/20 | train loss: 0.0295 | val loss: 0.0709 | val mAP@0.5: 0.9208 | time: 10.68s
# Epoch 11/20 | train loss: 0.0235 | val loss: 0.0649 | val mAP@0.5: 0.9223 | time: 11.10s
# Epoch 12/20 | train loss: 0.0177 | val loss: 0.0739 | val mAP@0.5: 0.9342 | time: 11.70s
# Epoch 13/20 | train loss: 0.0152 | val loss: 0.0902 | val mAP@0.5: 0.9231 | time: 14.20s
# Epoch 14/20 | train loss: 0.0124 | val loss: 0.0879 | val mAP@0.5: 0.9257 | time: 13.79s
# Epoch 15/20 | train loss: 0.0107 | val loss: 0.0931 | val mAP@0.5: 0.9250 | time: 15.84s
# Epoch 16/20 | train loss: 0.0095 | val loss: 0.0967 | val mAP@0.5: 0.9304 | time: 15.75s
# Epoch 17/20 | train loss: 0.0086 | val loss: 0.1026 | val mAP@0.5: 0.9310 | time: 15.76s
# Epoch 18/20 | train loss: 0.0082 | val loss: 0.1060 | val mAP@0.5: 0.9340 | time: 14.72s
# Epoch 19/20 | train loss: 0.0078 | val loss: 0.1084 | val mAP@0.5: 0.9324 | time: 17.15s
# Epoch 20/20 | train loss: 0.0077 | val loss: 0.1100 | val mAP@0.5: 0.9332 | time: 15.90s
# Best validation mAP@0.5: 0.9342
# Total training time: 261.37s
# run_09 validation mAP@0.5: 0.9342
#
# [10/12] run_10: {'model_name': 'deep', 'learning_rate': 0.001, 'weight_decay': 0.0001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.2564 | val loss: 0.1404 | val mAP@0.5: 0.6767 | time: 16.71s
# Epoch 02/20 | train loss: 0.0922 | val loss: 0.1124 | val mAP@0.5: 0.7237 | time: 16.01s
# Epoch 03/20 | train loss: 0.0708 | val loss: 0.0707 | val mAP@0.5: 0.8268 | time: 17.09s
# Epoch 04/20 | train loss: 0.0572 | val loss: 0.0663 | val mAP@0.5: 0.8806 | time: 16.49s
# Epoch 05/20 | train loss: 0.0526 | val loss: 0.0783 | val mAP@0.5: 0.8733 | time: 15.49s
# Epoch 06/20 | train loss: 0.0439 | val loss: 0.0829 | val mAP@0.5: 0.8947 | time: 14.61s
# Epoch 07/20 | train loss: 0.0393 | val loss: 0.0790 | val mAP@0.5: 0.8734 | time: 14.49s
# Epoch 08/20 | train loss: 0.0340 | val loss: 0.0689 | val mAP@0.5: 0.9109 | time: 16.82s
# Epoch 09/20 | train loss: 0.0295 | val loss: 0.0674 | val mAP@0.5: 0.9155 | time: 18.09s
# Epoch 10/20 | train loss: 0.0247 | val loss: 0.0758 | val mAP@0.5: 0.9286 | time: 18.40s
# Epoch 11/20 | train loss: 0.0193 | val loss: 0.0840 | val mAP@0.5: 0.9257 | time: 18.64s
# Epoch 12/20 | train loss: 0.0161 | val loss: 0.0841 | val mAP@0.5: 0.9321 | time: 16.07s
# Epoch 13/20 | train loss: 0.0138 | val loss: 0.0808 | val mAP@0.5: 0.9310 | time: 17.95s
# Epoch 14/20 | train loss: 0.0112 | val loss: 0.1173 | val mAP@0.5: 0.9328 | time: 17.94s
# Epoch 15/20 | train loss: 0.0092 | val loss: 0.1085 | val mAP@0.5: 0.9331 | time: 18.29s
# Epoch 16/20 | train loss: 0.0084 | val loss: 0.1262 | val mAP@0.5: 0.9347 | time: 17.50s
# Epoch 17/20 | train loss: 0.0076 | val loss: 0.1170 | val mAP@0.5: 0.9346 | time: 9.80s
# Epoch 18/20 | train loss: 0.0072 | val loss: 0.1235 | val mAP@0.5: 0.9380 | time: 11.90s
# Epoch 19/20 | train loss: 0.0070 | val loss: 0.1191 | val mAP@0.5: 0.9402 | time: 11.01s
# Epoch 20/20 | train loss: 0.0069 | val loss: 0.1240 | val mAP@0.5: 0.9355 | time: 10.74s
# Best validation mAP@0.5: 0.9402
# Total training time: 314.05s
# run_10 validation mAP@0.5: 0.9402
#
# [11/12] run_11: {'model_name': 'deep', 'learning_rate': 0.0005, 'weight_decay': 0.001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.3027 | val loss: 0.1180 | val mAP@0.5: 0.6584 | time: 12.59s
# Epoch 02/20 | train loss: 0.1067 | val loss: 0.0851 | val mAP@0.5: 0.7514 | time: 12.29s
# Epoch 03/20 | train loss: 0.0787 | val loss: 0.0782 | val mAP@0.5: 0.7956 | time: 12.31s
# Epoch 04/20 | train loss: 0.0638 | val loss: 0.1166 | val mAP@0.5: 0.8138 | time: 12.70s
# Epoch 05/20 | train loss: 0.0547 | val loss: 0.0628 | val mAP@0.5: 0.8175 | time: 11.89s
# Epoch 06/20 | train loss: 0.0478 | val loss: 0.0670 | val mAP@0.5: 0.8537 | time: 11.81s
# Epoch 07/20 | train loss: 0.0422 | val loss: 0.0833 | val mAP@0.5: 0.8544 | time: 12.29s
# Epoch 08/20 | train loss: 0.0371 | val loss: 0.0623 | val mAP@0.5: 0.8887 | time: 11.50s
# Epoch 09/20 | train loss: 0.0343 | val loss: 0.0767 | val mAP@0.5: 0.8997 | time: 12.21s
# Epoch 10/20 | train loss: 0.0297 | val loss: 0.0696 | val mAP@0.5: 0.9073 | time: 13.60s
# Epoch 11/20 | train loss: 0.0249 | val loss: 0.0655 | val mAP@0.5: 0.9020 | time: 11.81s
# Epoch 12/20 | train loss: 0.0222 | val loss: 0.0746 | val mAP@0.5: 0.9056 | time: 10.96s
# Epoch 13/20 | train loss: 0.0186 | val loss: 0.0880 | val mAP@0.5: 0.9071 | time: 11.93s
# Epoch 14/20 | train loss: 0.0161 | val loss: 0.0866 | val mAP@0.5: 0.9145 | time: 11.91s
# Epoch 15/20 | train loss: 0.0144 | val loss: 0.0911 | val mAP@0.5: 0.9162 | time: 11.20s
# Epoch 16/20 | train loss: 0.0133 | val loss: 0.1117 | val mAP@0.5: 0.9154 | time: 11.49s
# Epoch 17/20 | train loss: 0.0124 | val loss: 0.0959 | val mAP@0.5: 0.9170 | time: 11.70s
# Epoch 18/20 | train loss: 0.0117 | val loss: 0.0987 | val mAP@0.5: 0.9164 | time: 11.23s
# Epoch 19/20 | train loss: 0.0114 | val loss: 0.1002 | val mAP@0.5: 0.9171 | time: 11.08s
# Epoch 20/20 | train loss: 0.0111 | val loss: 0.1016 | val mAP@0.5: 0.9165 | time: 11.70s
# Best validation mAP@0.5: 0.9171
# Total training time: 238.28s
# run_11 validation mAP@0.5: 0.9171
#
# [12/12] run_12: {'model_name': 'deep', 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'num_epochs': 20}
# Epoch 01/20 | train loss: 0.3045 | val loss: 0.1345 | val mAP@0.5: 0.6674 | time: 13.41s
# Epoch 02/20 | train loss: 0.1069 | val loss: 0.0837 | val mAP@0.5: 0.7570 | time: 12.20s
# Epoch 03/20 | train loss: 0.0796 | val loss: 0.1462 | val mAP@0.5: 0.7673 | time: 11.65s
# Epoch 04/20 | train loss: 0.0634 | val loss: 0.0677 | val mAP@0.5: 0.8286 | time: 12.55s
# Epoch 05/20 | train loss: 0.0560 | val loss: 0.0744 | val mAP@0.5: 0.8281 | time: 11.86s
# Epoch 06/20 | train loss: 0.0484 | val loss: 0.0614 | val mAP@0.5: 0.8732 | time: 11.74s
# Epoch 07/20 | train loss: 0.0418 | val loss: 0.0621 | val mAP@0.5: 0.8748 | time: 11.80s
# Epoch 08/20 | train loss: 0.0362 | val loss: 0.0616 | val mAP@0.5: 0.8880 | time: 5.50s
# Epoch 09/20 | train loss: 0.0315 | val loss: 0.0733 | val mAP@0.5: 0.8970 | time: 6.69s
# Epoch 10/20 | train loss: 0.0290 | val loss: 0.0748 | val mAP@0.5: 0.8970 | time: 8.82s
# Epoch 11/20 | train loss: 0.0248 | val loss: 0.0673 | val mAP@0.5: 0.9134 | time: 8.18s
# Epoch 12/20 | train loss: 0.0212 | val loss: 0.0718 | val mAP@0.5: 0.9173 | time: 5.54s
# Epoch 13/20 | train loss: 0.0180 | val loss: 0.0725 | val mAP@0.5: 0.9139 | time: 10.11s
# Epoch 14/20 | train loss: 0.0160 | val loss: 0.0964 | val mAP@0.5: 0.9136 | time: 9.05s
# Epoch 15/20 | train loss: 0.0143 | val loss: 0.0934 | val mAP@0.5: 0.9135 | time: 5.84s
# Epoch 16/20 | train loss: 0.0128 | val loss: 0.0993 | val mAP@0.5: 0.9186 | time: 6.37s
# Epoch 17/20 | train loss: 0.0119 | val loss: 0.0970 | val mAP@0.5: 0.9258 | time: 6.54s
# Epoch 18/20 | train loss: 0.0114 | val loss: 0.0959 | val mAP@0.5: 0.9183 | time: 8.79s
# Epoch 19/20 | train loss: 0.0111 | val loss: 0.1001 | val mAP@0.5: 0.9213 | time: 8.04s
# Epoch 20/20 | train loss: 0.0108 | val loss: 0.1002 | val mAP@0.5: 0.9153 | time: 9.57s
# Best validation mAP@0.5: 0.9258
# Total training time: 184.26s
# run_12 validation mAP@0.5: 0.9258
#
# Best hyperparameters (by validation mAP@0.5):
# {'model_name': 'deep', 'learning_rate': 0.001, 'weight_decay': 0.0001, 'num_epochs': 20}
# Best run: run_10
# Best validation mAP@0.5: 0.9402

# %% [markdown]
# ## 10) Evaluation metrics
# This cell computes detection accuracy and IoU on cells that contain objects in ground truth.

# %%
def compute_detection_accuracy(model, loader):
    model.eval()
    total_object_cells = 0
    correct_predictions = 0

    with torch.no_grad():
        for images, targets in loader:
            images = images.to(device)
            targets = targets.to(device)
            predictions = model(images).permute(0, 2, 3, 1)

            true_object = targets[..., 0] > 0.5
            pred_object = torch.sigmoid(predictions[..., 0]) > 0.5
            pred_class = predictions[..., 5:].argmax(dim=-1)
            true_class = targets[..., 5].long()

            total_object_cells += true_object.sum().item()
            correct_predictions += (true_object & pred_object & (pred_class == true_class)).sum().item()

    return correct_predictions / total_object_cells if total_object_cells > 0 else 0.0


def compute_detection_iou(model, loader):
    model.eval()
    total_iou = 0.0
    total_object_cells = 0

    with torch.no_grad():
        for images, targets in loader:
            images = images.to(device)
            targets = targets.to(device)
            predictions = model(images).permute(0, 2, 3, 1)

            true_object = targets[..., 0] > 0.5
            if not true_object.any():
                continue

            pred_object = torch.sigmoid(predictions[..., 0]) > 0.5
            pred_xy = torch.sigmoid(predictions[..., 1:3])
            pred_wh = F.softplus(predictions[..., 3:5])
            pred_bbox = torch.cat([pred_xy, pred_wh], dim=-1)
            true_bbox = targets[..., 1:5]

            iou_values = xywh_iou(pred_bbox, true_bbox)
            iou_values = iou_values * pred_object.float()

            total_iou += iou_values[true_object].sum().item()
            total_object_cells += true_object.sum().item()

    return total_iou / total_object_cells if total_object_cells > 0 else 0.0

# %% [markdown]
# ## 11) Evaluate best tuned model on test set
#
# This cell evaluates the best model selected during hyperparameter tuning.

# %%
if 'best_model' not in globals() or best_model is None:
    raise RuntimeError('No tuned best model found. Run the hyperparameter tuning cell first.')

print(f"Best run from tuning: {best_model_name}")
print(f"Best hyperparameters: {best_hyperparameters}")
print(f"Best validation mAP@0.5: {best_map50:.4f}")

test_accuracy = compute_detection_accuracy(best_model, test_loader)
test_iou = compute_detection_iou(best_model, test_loader)
test_overall = 0.5 * (test_accuracy + test_iou)
test_map_results = get_map_results(best_model, test_loader, device)

print(f"Test accuracy: {test_accuracy:.4f}")
print(f"Test IoU:      {test_iou:.4f}")
print(f"Test overall:  {test_overall:.4f}")
print(f"Test mAP@0.5:  {float(test_map_results['map_50'].item()):.4f}")
print(f"Test mAP:      {float(test_map_results['map'].item()):.4f}")
# Out:
# Best run from tuning: run_10
# Best hyperparameters: {'model_name': 'deep', 'learning_rate': 0.001, 'weight_decay': 0.0001, 'num_epochs': 20}
# Best validation mAP@0.5: 0.9402
# Test accuracy: 0.9672
# Test IoU:      0.7502
# Test overall:  0.8587
# Test mAP@0.5:  0.9363
# Test mAP:      0.5105

# %% [markdown]
# ## 11b) Sklearn Classification Evaluation
# This cell converts the detector outputs into sklearn-compatible class labels per grid cell and reports classification metrics plus a confusion matrix for the test split.

# %%
def prepare_sklearn_label_arrays(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=np.int64).reshape(-1)
    y_pred = np.asarray(y_pred, dtype=np.int64).reshape(-1)

    if y_true.shape != y_pred.shape:
        raise ValueError(
            f"Expected y_true and y_pred to have the same shape, got {y_true.shape} and {y_pred.shape}."
        )
    if y_true.size == 0:
        raise ValueError("No evaluation samples were collected from the loader.")

    return y_true, y_pred


def summarize_sklearn_classification(y_true, y_pred, label_names, title):
    y_true, y_pred = prepare_sklearn_label_arrays(y_true, y_pred)
    label_ids = np.arange(len(label_names))
    observed_label_ids = np.unique(np.concatenate([y_true, y_pred]))

    accuracy = accuracy_score(y_true, y_pred)
    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=observed_label_ids,
        average='macro',
        zero_division=0,
    )
    precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=observed_label_ids,
        average='weighted',
        zero_division=0,
    )
    cm = confusion_matrix(y_true, y_pred, labels=label_ids)

    print(title)
    print('-' * len(title))
    print(f"Accuracy             : {accuracy:.4f}")
    print(f"Precision (macro)    : {precision_macro:.4f}")
    print(f"Recall (macro)       : {recall_macro:.4f}")
    print(f"Precision (weighted) : {precision_weighted:.4f}")
    print(f"Recall (weighted)    : {recall_weighted:.4f}")
    print(f"F1-score (macro)     : {f1_macro:.4f}")
    print(f"F1-score (weighted)  : {f1_weighted:.4f}")

    fig, ax = plt.subplots(figsize=(8, 6))
    if sns is not None:
        sns.heatmap(
            cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=label_names,
            yticklabels=label_names,
            cbar=False,
            ax=ax,
        )
    else:
        image = ax.imshow(cm, cmap='Blues')
        fig.colorbar(image, ax=ax, fraction=0.046, pad=0.04)
        ax.set_xticks(np.arange(len(label_names)))
        ax.set_yticks(np.arange(len(label_names)))
        ax.set_xticklabels(label_names)
        ax.set_yticklabels(label_names)
        for row in range(cm.shape[0]):
            for col in range(cm.shape[1]):
                ax.text(col, row, int(cm[row, col]), ha='center', va='center', color='black')

    ax.set_title(f"{title}\nConfusion Matrix")
    ax.set_xlabel('Predicted label')
    ax.set_ylabel('True label')
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
    plt.setp(ax.get_yticklabels(), rotation=0)
    plt.tight_layout()
    plt.show()

    print(
        "Interpretation: These sklearn scores evaluate the classification side of the detector "
        "(background vs object class). Compare accuracy with macro F1 because background cells can "
        "dominate the split, and use the off-diagonal counts to spot the main confusions."
    )

    return {
        'accuracy': accuracy,
        'precision_macro': precision_macro,
        'recall_macro': recall_macro,
        'precision_weighted': precision_weighted,
        'recall_weighted': recall_weighted,
        'f1_macro': f1_macro,
        'f1_weighted': f1_weighted,
        'confusion_matrix': cm,
        'label_names': label_names,
    }


def collect_detection_classification_labels(model, loader, object_threshold=0.5):
    # Treat every output grid cell as a sklearn target: background (0) or a class id (1..NUM_CLASSES).
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for images, targets in loader:
            images = images.to(device)
            targets = targets.to(device)
            outputs = model(images).permute(0, 2, 3, 1)

            true_object = targets[..., 0] > 0.5
            pred_object = torch.sigmoid(outputs[..., 0]) > object_threshold
            true_class = targets[..., 5].long() + 1
            pred_class = outputs[..., 5:].argmax(dim=-1).long() + 1
            background = torch.zeros_like(true_class)

            batch_true = torch.where(true_object, true_class, background)
            batch_pred = torch.where(pred_object, pred_class, background)

            y_true.extend(batch_true.detach().cpu().reshape(-1).tolist())
            y_pred.extend(batch_pred.detach().cpu().reshape(-1).tolist())

    return y_true, y_pred


evaluation_model = globals().get('best_model', globals().get('model', None))
if evaluation_model is None:
    raise RuntimeError('No trained model found. Run the training/model-selection cells first.')

object_threshold = 0.5
detection_label_names = ['Background'] + list(globals().get('eda_class_names', [f'Class {idx}' for idx in range(NUM_CLASSES)]))
y_true_detection, y_pred_detection = collect_detection_classification_labels(
    evaluation_model,
    test_loader,
    object_threshold=object_threshold,
)

sklearn_detection_results = summarize_sklearn_classification(
    y_true_detection,
    y_pred_detection,
    label_names=detection_label_names,
    title='Detection Test Set Sklearn Evaluation',
)
# Out:
# Detection Test Set Sklearn Evaluation
# -------------------------------------
# Accuracy             : 0.9821
# Precision (macro)    : 0.9628
# Recall (macro)       : 0.9736
# Precision (weighted) : 0.9823
# Recall (weighted)    : 0.9821
# F1-score (macro)     : 0.9681
# F1-score (weighted)  : 0.9822
# Interpretation: These sklearn scores evaluate the classification side of the detector (background vs object class). Compare accuracy with macro F1 because background cells can dominate the split, and use the off-diagonal counts to spot the main confusions.

# %% [markdown]
# ## 12) Prediction decoding and visualization helpers
# These helpers convert model outputs to global boxes and draw both true and predicted boxes on images.

# %%
def decode_true_boxes(target_grid):
    boxes = []
    for row in range(H_OUT):
        for col in range(W_OUT):
            cell = target_grid[row, col]
            if cell[0] > 0.5:
                global_box = local_to_global(row, col, cell[1:5])
                label = int(cell[5].item())
                boxes.append((global_box, label))
    return boxes


def decode_pred_boxes(pred_grid, object_threshold=0.5):
    pred_grid = pred_grid.permute(1, 2, 0)
    boxes = []

    for row in range(H_OUT):
        for col in range(W_OUT):
            cell = pred_grid[row, col]
            object_score = torch.sigmoid(cell[0]).item()
            if object_score > object_threshold:
                px = torch.sigmoid(cell[1]).item()
                py = torch.sigmoid(cell[2]).item()
                pw = F.softplus(cell[3]).item()
                ph = F.softplus(cell[4]).item()
                class_probabilities = F.softmax(cell[5:], dim=0)
                label = int(torch.argmax(class_probabilities).item())
                score = object_score * class_probabilities[label].item()
                global_box = local_to_global(row, col, torch.tensor([px, py, pw, ph]))
                boxes.append((global_box, label, score))

    return boxes


def draw_box(ax, box_xywh, color, text=None):
    x, y, w, h = box_xywh
    x1 = (x - 0.5 * w) * W_IN
    y1 = (y - 0.5 * h) * H_IN
    width = w * W_IN
    height = h * H_IN

    rectangle = patches.Rectangle((x1, y1), width, height, linewidth=2, edgecolor=color, facecolor='none')
    ax.add_patch(rectangle)

    if text is not None:
        ax.text(x1, max(0, y1 - 2), text, color=color, fontsize=8, backgroundcolor='black')

# %% [markdown]
# ## 13) Plot prediction examples
# This cell plots samples from train, validation, and test data with true (green) and predicted (red) bounding boxes and labels.

# %%
plot_model = globals().get('best_model', globals().get('model', None))
if plot_model is None:
    raise RuntimeError('No trained model found. Run training and model selection first.')

plot_model.eval()

splits = [
    ('Train', train_data),
    ('Validation', val_data),
    ('Test', test_data),
]

samples_per_split = 3
figure, axes = plt.subplots(len(splits), samples_per_split, figsize=(4.2 * samples_per_split, 3.6 * len(splits)))

with torch.no_grad():
    for row, (split_name, dataset) in enumerate(splits):
        indices = torch.randperm(len(dataset))[:samples_per_split]

        for col, index in enumerate(indices):
            ax = axes[row, col] if len(splits) > 1 else axes[col]
            image, target = dataset[int(index)]
            image = ensure_channel_first(image)

            model_input = preprocessor(image).unsqueeze(0).to(device)
            prediction = plot_model(model_input).cpu().squeeze(0)

            true_boxes = decode_true_boxes(target)
            pred_boxes = decode_pred_boxes(prediction, object_threshold=0.5)

            ax.imshow(image.squeeze(0), cmap='gray')

            true_labels = []
            pred_labels = []

            for box, label in true_boxes:
                true_labels.append(str(label))
                draw_box(ax, box, color='lime', text=f"T:{label}")

            for box, label, score in pred_boxes:
                pred_labels.append(str(label))
                draw_box(ax, box, color='red', text=f"P:{label} ({score:.2f})")

            ax.set_title(
                f"{split_name} | true [{', '.join(true_labels) if true_labels else '-'}] "
                f"pred [{', '.join(pred_labels) if pred_labels else '-'}]",
                fontsize=8,
            )
            ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 14) Per-model loss graphs

# %%
def compute_average_detection_loss(model, loader):
    model.eval()
    total_loss = 0.0
    total_samples = 0

    with torch.no_grad():
        for images, targets in loader:
            images = images.to(device)
            targets = targets.to(device)
            predictions = model(images)

            batch_size = images.size(0)
            total_loss += detection_loss(predictions, targets).item() * batch_size
            total_samples += batch_size

    if total_samples == 0:
        return float('nan')
    return total_loss / total_samples


if 'training_histories' not in globals() or len(training_histories) == 0:
    raise RuntimeError('No training histories found. Run the hyperparameter tuning cell first.')

def format_hparam_value(value):
    if isinstance(value, float):
        if value == 0:
            return '0'
        if abs(value) < 1e-2 or abs(value) >= 1e3:
            return f'{value:.0e}'
        return f'{value:g}'
    return str(value)

def build_detection_run_metadata():
    metadata = {}

    if 'tuning_results' in globals():
        for result in tuning_results:
            if isinstance(result, dict) and result.get('run_name') is not None:
                metadata[result['run_name']] = result

    if not metadata and 'keys' in globals() and 'all_combinations' in globals():
        for run_index, values in enumerate(all_combinations, start=1):
            metadata[f'run_{run_index:02d}'] = dict(zip(keys, values))

    return metadata

def build_detection_title(run_name, run_info):
    if not isinstance(run_info, dict):
        return run_name

    label_map = {
        'learning_rate': 'lr',
        'weight_decay': 'wd',
        'num_epochs': 'epochs',
    }
    model_name = str(run_info.get('model_name', run_name))
    parts = []

    for key, value in run_info.items():
        if key in {'run_name', 'model_name', 'val_map50'}:
            continue
        parts.append(f"{label_map.get(key, key)}={format_hparam_value(value)}")

    if not parts:
        return model_name
    return f"{model_name} | {', '.join(parts)}"

loss_histories = {
    model_name: {
        'train_loss': list(history.get('train_loss', [])),
        'val_loss': list(history.get('val_loss', [])),
        'val_map50': list(history.get('val_map50', [])),
    }
    for model_name, history in training_histories.items()
}

run_metadata = build_detection_run_metadata()
ordered_model_names = list(loss_histories.keys())
print(f'Creating {len(ordered_model_names)} per-model loss and mAP graphs.')

for run_name in ordered_model_names:
    history = loss_histories[run_name]
    train_losses = history['train_loss']
    val_losses = history['val_loss']
    val_map50s = history['val_map50']
    if len(train_losses) == 0 or len(val_losses) == 0:
        raise RuntimeError(f'Model {run_name} is missing train_loss or val_loss values.')
    if len(val_map50s) == 0:
        raise RuntimeError(f'Model {run_name} is missing val_map50 values.')

    epochs = list(range(1, len(train_losses) + 1))
    title = build_detection_title(run_name, run_metadata.get(run_name))
    figure, axis = plt.subplots(figsize=(8, 4.5))
    axis.plot(epochs, train_losses, marker='o', linewidth=2, label='Training Loss', color='#4C78A8')
    axis.plot(epochs, val_losses, marker='s', linewidth=2, label='Validation Loss', color='#F58518')
    axis.set_title(f'Train vs Validation Loss\n{title}')
    axis.set_xlabel('Epoch')
    axis.set_ylabel('Loss')
    axis.set_xticks(epochs)
    axis.legend()
    axis.grid(True, linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.show()

    best_epoch = int(np.argmax(val_map50s)) + 1
    best_val_map50 = val_map50s[best_epoch - 1]
    figure, axis = plt.subplots(figsize=(8, 4.5))
    axis.plot(epochs, val_map50s, marker='o', linewidth=2, label='Validation mAP@0.5', color='#54A24B')
    axis.axvline(best_epoch, linestyle='--', linewidth=1.5, color='#E45756', label=f'Best epoch: {best_epoch}')
    axis.scatter([best_epoch], [best_val_map50], color='#E45756', s=60, zorder=3)
    axis.set_title(f'Validation mAP@0.5\n{title}')
    axis.set_xlabel('Epoch')
    axis.set_ylabel('mAP@0.5')
    axis.set_xticks(epochs)
    axis.legend()
    axis.grid(True, linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
# Creating 12 per-model loss and mAP graphs.
