# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms
import matplotlib.pyplot as plt
from math import ceil, floor
from datetime import datetime 
import time
from torch.utils.data import Dataset, DataLoader
from itertools import product
from torch.utils.data.dataset import TensorDataset

torch.manual_seed(123)

# %% [markdown]
# # Model definition

# %%
device = (torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))
print(f"Training on device {device}.")

NUM_CLASSES = 10
IMAGE_HEIGHT, IMAGE_WIDTH = 48, 60


class LocalizationCNN(nn.Module):
    def __init__(self, channels=(16, 32, 64), hidden_dim=256, dropout=0.0, num_classes=NUM_CLASSES):
        super().__init__()
        blocks = []
        in_ch = 1
        for out_ch in channels:
            blocks.extend([
                nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(2),
            ])
            in_ch = out_ch

        self.features = nn.Sequential(*blocks)

        with torch.no_grad():
            dummy = torch.zeros(1, 1, IMAGE_HEIGHT, IMAGE_WIDTH)
            feat_dim = self.features(dummy).reshape(1, -1).shape[1]

        self.head = nn.Sequential(
            nn.Flatten(),
            nn.Linear(feat_dim, hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes + 5),
        )

    def forward(self, x):
        return self.head(self.features(x))


model_configs = {
    'small': {'channels': (16, 32), 'hidden_dim': 128, 'dropout': 0.10},
    'base': {'channels': (16, 32, 64), 'hidden_dim': 256, 'dropout': 0.15},
    'deep': {'channels': (16, 32, 64, 96), 'hidden_dim': 256, 'dropout': 0.20},
}
# Out:
# Training on device cuda.

# %% [markdown]
# ## Localization

# %%
def localization_loss(y_pred, y_true):
    obj_true = y_true[:, 0].float()

    detection_loss = F.binary_cross_entropy_with_logits(
        y_pred[:, 0], obj_true, reduction='none'
    )

    bbox_loss = F.mse_loss(
        torch.sigmoid(y_pred[:, 1:5]), y_true[:, 1:5].float(), reduction='none'
    ).mean(dim=1)

    class_targets = y_true[:, 5].long().clamp(min=0, max=y_pred.shape[1] - 6)
    class_loss = F.cross_entropy(y_pred[:, 5:], class_targets, reduction='none')

    total_loss = torch.where(
        obj_true > 0.5,
        detection_loss + bbox_loss + class_loss,
        detection_loss,
    )
    return total_loss.mean()

# %% [markdown]
# ### Load data and preprocessing

# %%
data_path = '../data_2/'


def safe_load(path):
    if hasattr(torch.serialization, 'safe_globals'):
        with torch.serialization.safe_globals([TensorDataset]):
            return torch.load(path, map_location='cpu')
    torch.serialization.add_safe_globals([TensorDataset])
    return torch.load(path, map_location='cpu')


train_data = safe_load(f"{data_path}localization_train.pt")
val_data = safe_load(f"{data_path}localization_val.pt")
test_data = safe_load(f"{data_path}localization_test.pt")

print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 59400
# 6600
# 11000

# %% [markdown]
# ### Exploratory Data Analysis
# This section summarizes the dataset, checks class balance across splits, and visualizes a few annotated test samples before normalization and training.

# %%
# Collect per-split class counts and a few summary statistics.
eda_class_names = [f"Class {class_idx}" for class_idx in range(NUM_CLASSES)]
localization_splits = {
    "Train": train_data,
    "Validation": val_data,
    "Test": test_data,
}

split_class_counts = {}
split_metadata = {}

for split_name, dataset in localization_splits.items():
    class_counts = torch.zeros(NUM_CLASSES, dtype=torch.long)
    object_count = 0
    bbox_areas = []

    for _, target in dataset:
        target = target.float()
        has_object = bool(target[0].item() > 0.5)
        if not has_object:
            continue

        object_count += 1
        label = int(target[5].item())
        class_counts[label] += 1
        bbox_areas.append(float((target[3] * target[4]).item()))

    split_class_counts[split_name] = class_counts
    split_metadata[split_name] = {
        "samples": len(dataset),
        "object_samples": object_count,
        "background_samples": len(dataset) - object_count,
        "avg_bbox_area": sum(bbox_areas) / len(bbox_areas) if bbox_areas else 0.0,
    }

overall_class_counts = torch.stack(list(split_class_counts.values())).sum(dim=0)
sample_image, sample_target = train_data[0]

print("Dataset summary")
print(f"Image size: {tuple(sample_image.shape[-2:])} | Number of classes: {NUM_CLASSES}")
print(
    f"Target format: [objectness, x_center, y_center, width, height, class_id] | "
    f"target shape: {tuple(sample_target.shape)}"
)
for split_name, metadata in split_metadata.items():
    print(
        f"{split_name}: {metadata['samples']} samples | "
        f"{metadata['object_samples']} labeled objects | "
        f"{metadata['background_samples']} background-only samples | "
        f"avg box area: {metadata['avg_bbox_area']:.4f}"
    )
print(
    "Overall class counts: "
    + ", ".join(
        f"{class_name}={int(count)}"
        for class_name, count in zip(eda_class_names, overall_class_counts.tolist())
    )
)

# Visualize the class distribution for each split.
class_positions = torch.arange(NUM_CLASSES, dtype=torch.float32)
bar_width = 0.25
split_colors = {
    "Train": "#4C78A8",
    "Validation": "#F58518",
    "Test": "#54A24B",
}

fig, ax = plt.subplots(figsize=(12, 4.5))
for offset, (split_name, counts) in enumerate(split_class_counts.items()):
    shift = (offset - (len(split_class_counts) - 1) / 2) * bar_width
    ax.bar(
        (class_positions + shift).tolist(),
        counts.tolist(),
        width=bar_width,
        label=split_name,
        color=split_colors[split_name],
    )

ax.set_title("Localization class distribution by split")
ax.set_xlabel("Class label")
ax.set_ylabel("Samples")
ax.set_xticks(class_positions.tolist())
ax.set_xticklabels(eda_class_names, rotation=45, ha="right")
ax.legend()
ax.grid(axis="y", linestyle="--", alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Dataset summary
# Image size: (48, 60) | Number of classes: 10
# Target format: [objectness, x_center, y_center, width, height, class_id] | target shape: (6,)
# Train: 59400 samples | 54000 labeled objects | 5400 background-only samples | avg box area: 0.0947
# Validation: 6600 samples | 6000 labeled objects | 600 background-only samples | avg box area: 0.0936
# Test: 11000 samples | 10000 labeled objects | 1000 background-only samples | avg box area: 0.0943
# Overall class counts: Class 0=6903, Class 1=7877, Class 2=6990, Class 3=7141, Class 4=6824, Class 5=6313, Class 6=6876, Class 7=7293, Class 8=6825, Class 9=6958

# %%
# Plot a small, evenly spaced subset of the test set with localization annotations.
def _eda_bbox_center_to_rect(target, image_height=IMAGE_HEIGHT, image_width=IMAGE_WIDTH):
    x_center, y_center, box_w, box_h = target[1:5].tolist()
    left = (x_center - 0.5 * box_w) * image_width
    top = (y_center - 0.5 * box_h) * image_height
    return left, top, box_w * image_width, box_h * image_height


num_samples = min(6, len(test_data))
sample_indices = torch.linspace(0, len(test_data) - 1, steps=num_samples).long().tolist()
num_cols = min(3, num_samples)
num_rows = (num_samples + num_cols - 1) // num_cols

fig, axes = plt.subplots(num_rows, num_cols, figsize=(4.5 * num_cols, 3.8 * num_rows))
if hasattr(axes, "ravel"):
    axes = axes.ravel()
else:
    axes = [axes]

for ax, sample_idx in zip(axes, sample_indices):
    image, target = test_data[int(sample_idx)]
    image = image.float()
    if image.ndim == 3:
        image = image.squeeze(0)
    target = target.float()

    ax.imshow(image, cmap="gray")

    if target[0].item() > 0.5:
        left, top, width, height = _eda_bbox_center_to_rect(target)
        label_name = eda_class_names[int(target[5].item())]
        ax.add_patch(
            plt.Rectangle((left, top), width, height, fill=False, edgecolor="lime", linewidth=2)
        )
        ax.text(
            left,
            max(top - 1, 0),
            label_name,
            fontsize=8,
            color="black",
            bbox=dict(facecolor="lime", alpha=0.75, pad=1.5),
        )
        ax.set_title(f"Test sample {sample_idx}\nLabel: {label_name}", fontsize=9)
    else:
        ax.set_title(f"Test sample {sample_idx}\nBackground only", fontsize=9)

    ax.axis("off")

for ax in axes[len(sample_indices):]:
    ax.axis("off")

plt.suptitle("Annotated samples from the localization test set", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Normalize Images

# %%
def _ensure_channel_first(image):
    image = image.float()
    if image.ndim == 2:
        image = image.unsqueeze(0)
    return image


class LocalizationDataset(Dataset):
    def __init__(self, data, preprocessor=None):
        self.data = data
        self.preprocessor = preprocessor

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image, target = self.data[idx]
        image = _ensure_channel_first(image)
        target = target.float()
        if self.preprocessor is not None:
            image = self.preprocessor(image)
        return image, target


train_images = torch.stack([_ensure_channel_first(x) for x, _ in train_data], dim=0)
train_mean = train_images.mean()
train_std = train_images.std().clamp_min(1e-6)
print(f"Train mean: {train_mean.item():.4f}, train std: {train_std.item():.4f}")


def preprocessor(x):
    return (x - train_mean) / train_std


batch_size = 128
train_loader = DataLoader(LocalizationDataset(train_data, preprocessor), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(LocalizationDataset(val_data, preprocessor), batch_size=batch_size, shuffle=False)
test_loader = DataLoader(LocalizationDataset(test_data, preprocessor), batch_size=batch_size, shuffle=False)
# Out:
# Train mean: 0.4171, train std: 0.2138

# %% [markdown]
# ### Hyperparameter tuning and training

# %%
def train_single_model(model, train_loader, val_loader, num_epochs=10, lr=1e-3, weight_decay=0.0):
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    history = {
        'train_loss': [],
        'val_loss': [],
        'val_acc': [],
        'val_iou': [],
        'val_overall': [],
    }

    best_val_overall = float('-inf')
    best_state = None

    for epoch in range(num_epochs):
        model.train()
        running_train_loss = 0.0

        for images, targets in train_loader:
            images = images.to(device)
            targets = targets.to(device)

            optimizer.zero_grad()
            preds = model(images)
            loss = localization_loss(preds, targets)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item() * images.size(0)

        train_loss = running_train_loss / len(train_loader.dataset)

        model.eval()
        running_val_loss = 0.0
        correct = 0
        total_iou = 0.0
        total_objects = 0

        with torch.no_grad():
            for images, targets in val_loader:
                images = images.to(device)
                targets = targets.to(device)
                preds = model(images)
                loss = localization_loss(preds, targets)
                running_val_loss += loss.item() * images.size(0)

                true_obj = targets[:, 0] > 0.5
                if not true_obj.any():
                    continue

                pred_obj = torch.sigmoid(preds[:, 0]) > 0.5
                pred_cls = preds[:, 5:].argmax(dim=1)
                true_cls = targets[:, 5].long()

                correct += (pred_obj & (pred_cls == true_cls) & true_obj).sum().item()

                pred_bbox = torch.sigmoid(preds[:, 1:5])[true_obj]
                true_bbox = targets[:, 1:5][true_obj]
                detected = pred_obj[true_obj]

                pred_min = pred_bbox[:, :2] - 0.5 * pred_bbox[:, 2:]
                pred_max = pred_bbox[:, :2] + 0.5 * pred_bbox[:, 2:]
                true_min = true_bbox[:, :2] - 0.5 * true_bbox[:, 2:]
                true_max = true_bbox[:, :2] + 0.5 * true_bbox[:, 2:]

                inter_min = torch.maximum(pred_min, true_min)
                inter_max = torch.minimum(pred_max, true_max)
                inter_wh = (inter_max - inter_min).clamp(min=0)
                inter_area = inter_wh[:, 0] * inter_wh[:, 1]

                pred_area = (pred_bbox[:, 2] * pred_bbox[:, 3]).clamp(min=0)
                true_area = (true_bbox[:, 2] * true_bbox[:, 3]).clamp(min=0)
                union_area = pred_area + true_area - inter_area
                iou = torch.where(union_area > 0, inter_area / union_area, torch.zeros_like(union_area))
                iou = iou * detected.float()

                total_iou += iou.sum().item()
                total_objects += true_obj.sum().item()

        val_loss = running_val_loss / len(val_loader.dataset)
        val_acc = correct / total_objects if total_objects > 0 else 0.0
        val_iou = total_iou / total_objects if total_objects > 0 else 0.0
        val_overall = 0.5 * (val_acc + val_iou)

        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        history['val_iou'].append(val_iou)
        history['val_overall'].append(val_overall)

        if val_overall > best_val_overall:
            best_val_overall = val_overall
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

        print(
            f"Epoch {epoch + 1:02d}/{num_epochs} | "
            f"train loss: {train_loss:.4f} | val loss: {val_loss:.4f} | "
            f"val acc: {val_acc:.4f} | val IoU: {val_iou:.4f} | val overall: {val_overall:.4f}"
        )

    if best_state is not None:
        model.load_state_dict(best_state)

    return model, history, best_val_overall


hyperparam_grid = {
    'model_name': ['small', 'base', 'deep'],
    'lr': [1e-3, 5e-4],
    'weight_decay': [0.0, 1e-4],
    'num_epochs': [20],
}

hyperparam_candidates = [
    {
        'model_name': model_name,
        'lr': lr,
        'weight_decay': weight_decay,
        'num_epochs': num_epochs,
    }
    for model_name, lr, weight_decay, num_epochs in product(
        hyperparam_grid['model_name'],
        hyperparam_grid['lr'],
        hyperparam_grid['weight_decay'],
        hyperparam_grid['num_epochs'],
    )
]

trained_models = {}
training_histories = {}
tuning_results = []
total_start = time.perf_counter()

for trial_idx, candidate in enumerate(hyperparam_candidates, start=1):
    trial_start = time.perf_counter()
    model_name = candidate['model_name']
    lr = candidate['lr']
    weight_decay = candidate['weight_decay']
    num_epochs = candidate['num_epochs']
    cfg = model_configs[model_name]
    trial_name = (
        f"trial_{trial_idx:02d}_{model_name}_"
        f"lr{lr:.0e}_wd{weight_decay:.0e}_e{num_epochs}"
    )

    print(
        f"\n[{trial_idx}/{len(hyperparam_candidates)}] {trial_name} | "
        f"channels={cfg['channels']} hidden={cfg['hidden_dim']} dropout={cfg['dropout']}"
    )
    current_model = LocalizationCNN(**cfg).to(device)
    current_model, history, best_val_overall = train_single_model(
        current_model,
        train_loader,
        val_loader,
        num_epochs=num_epochs,
        lr=lr,
        weight_decay=weight_decay,
    )
    trial_seconds = time.perf_counter() - trial_start

    trained_models[trial_name] = current_model
    training_histories[trial_name] = history
    tuning_results.append({
        'trial_name': trial_name,
        'model_name': model_name,
        'lr': lr,
        'weight_decay': weight_decay,
        'num_epochs': num_epochs,
        'best_val_overall': best_val_overall,
        'train_seconds': trial_seconds,
    })
    print(
        f"Best val overall for {trial_name}: {best_val_overall:.4f} | "
        f"trial time: {trial_seconds:.1f}s ({trial_seconds / 60:.2f} min)"
    )

total_seconds = time.perf_counter() - total_start
tuning_results = sorted(tuning_results, key=lambda d: d['best_val_overall'], reverse=True)

print(
    f"\nTotal tuning/training time: {total_seconds:.1f}s "
    f"({total_seconds / 60:.2f} min)"
)
print('\nHyperparameter tuning summary (sorted by best val overall):')
for result in tuning_results:
    print(
        f"{result['trial_name']:>36s} | "
        f"best val overall: {result['best_val_overall']:.4f} | "
        f"time: {result['train_seconds']:.1f}s"
    )

best_trial_name = tuning_results[0]['trial_name']
model = trained_models[best_trial_name]
print(f"\nSelected best tuning trial: {best_trial_name}")
# Out:
# [1/12] trial_01_small_lr1e-03_wd0e+00_e20 | channels=(16, 32) hidden=128 dropout=0.1
# Epoch 01/20 | train loss: 1.9768 | val loss: 1.7163 | val acc: 0.3315 | val IoU: 0.4520 | val overall: 0.3918
# Epoch 02/20 | train loss: 1.4981 | val loss: 1.3266 | val acc: 0.5010 | val IoU: 0.4778 | val overall: 0.4894
# Epoch 03/20 | train loss: 1.1873 | val loss: 1.0985 | val acc: 0.5945 | val IoU: 0.4722 | val overall: 0.5334
# Epoch 04/20 | train loss: 0.9657 | val loss: 0.9725 | val acc: 0.6542 | val IoU: 0.4747 | val overall: 0.5644
# Epoch 05/20 | train loss: 0.7963 | val loss: 0.8479 | val acc: 0.6937 | val IoU: 0.4524 | val overall: 0.5730
# Epoch 06/20 | train loss: 0.6646 | val loss: 0.8227 | val acc: 0.7043 | val IoU: 0.4489 | val overall: 0.5766
# Epoch 07/20 | train loss: 0.5675 | val loss: 0.7548 | val acc: 0.7317 | val IoU: 0.4503 | val overall: 0.5910
# Epoch 08/20 | train loss: 0.4845 | val loss: 0.8152 | val acc: 0.7122 | val IoU: 0.4402 | val overall: 0.5762
# Epoch 09/20 | train loss: 0.4175 | val loss: 0.7775 | val acc: 0.7290 | val IoU: 0.4366 | val overall: 0.5828
# Epoch 10/20 | train loss: 0.3623 | val loss: 0.8519 | val acc: 0.7212 | val IoU: 0.4419 | val overall: 0.5815
# Epoch 11/20 | train loss: 0.3071 | val loss: 0.8146 | val acc: 0.7383 | val IoU: 0.4356 | val overall: 0.5870
# Epoch 12/20 | train loss: 0.2686 | val loss: 0.8152 | val acc: 0.7397 | val IoU: 0.4320 | val overall: 0.5858
# Epoch 13/20 | train loss: 0.2351 | val loss: 0.8905 | val acc: 0.7330 | val IoU: 0.4474 | val overall: 0.5902
# Epoch 14/20 | train loss: 0.2119 | val loss: 0.9068 | val acc: 0.7398 | val IoU: 0.4395 | val overall: 0.5897
# Epoch 15/20 | train loss: 0.1837 | val loss: 0.9483 | val acc: 0.7368 | val IoU: 0.4396 | val overall: 0.5882
# Epoch 16/20 | train loss: 0.1745 | val loss: 1.0222 | val acc: 0.7217 | val IoU: 0.4246 | val overall: 0.5731
# Epoch 17/20 | train loss: 0.1521 | val loss: 1.0655 | val acc: 0.7262 | val IoU: 0.4342 | val overall: 0.5802
# Epoch 18/20 | train loss: 0.1387 | val loss: 1.1175 | val acc: 0.7288 | val IoU: 0.4429 | val overall: 0.5859
# Epoch 19/20 | train loss: 0.1305 | val loss: 1.1403 | val acc: 0.7240 | val IoU: 0.4421 | val overall: 0.5830
# Epoch 20/20 | train loss: 0.1237 | val loss: 1.2303 | val acc: 0.7242 | val IoU: 0.4497 | val overall: 0.5869
# Best val overall for trial_01_small_lr1e-03_wd0e+00_e20: 0.5910 | trial time: 72.0s (1.20 min)
#
# [2/12] trial_02_small_lr1e-03_wd1e-04_e20 | channels=(16, 32) hidden=128 dropout=0.1
# Epoch 01/20 | train loss: 1.9992 | val loss: 1.7533 | val acc: 0.3153 | val IoU: 0.4611 | val overall: 0.3882
# Epoch 02/20 | train loss: 1.5481 | val loss: 1.4388 | val acc: 0.4420 | val IoU: 0.4599 | val overall: 0.4510
# Epoch 03/20 | train loss: 1.2842 | val loss: 1.1985 | val acc: 0.5600 | val IoU: 0.4644 | val overall: 0.5122
# Epoch 04/20 | train loss: 1.0970 | val loss: 1.0564 | val acc: 0.6218 | val IoU: 0.4467 | val overall: 0.5343
# Epoch 05/20 | train loss: 0.9375 | val loss: 0.9597 | val acc: 0.6583 | val IoU: 0.4341 | val overall: 0.5462
# Epoch 06/20 | train loss: 0.8042 | val loss: 0.9480 | val acc: 0.6512 | val IoU: 0.4246 | val overall: 0.5379
# Epoch 07/20 | train loss: 0.6924 | val loss: 0.7862 | val acc: 0.7250 | val IoU: 0.4585 | val overall: 0.5918
# Epoch 08/20 | train loss: 0.5934 | val loss: 0.7353 | val acc: 0.7427 | val IoU: 0.4453 | val overall: 0.5940
# Epoch 09/20 | train loss: 0.5130 | val loss: 0.7578 | val acc: 0.7398 | val IoU: 0.4513 | val overall: 0.5956
# Epoch 10/20 | train loss: 0.4472 | val loss: 0.7433 | val acc: 0.7457 | val IoU: 0.4421 | val overall: 0.5939
# Epoch 11/20 | train loss: 0.3832 | val loss: 0.7165 | val acc: 0.7547 | val IoU: 0.4471 | val overall: 0.6009
# Epoch 12/20 | train loss: 0.3364 | val loss: 0.7435 | val acc: 0.7553 | val IoU: 0.4726 | val overall: 0.6140
# Epoch 13/20 | train loss: 0.2909 | val loss: 0.7761 | val acc: 0.7508 | val IoU: 0.4884 | val overall: 0.6196
# Epoch 14/20 | train loss: 0.2618 | val loss: 0.7770 | val acc: 0.7558 | val IoU: 0.5110 | val overall: 0.6334
# Epoch 15/20 | train loss: 0.2318 | val loss: 0.8212 | val acc: 0.7485 | val IoU: 0.5214 | val overall: 0.6349
# Epoch 16/20 | train loss: 0.2023 | val loss: 0.8435 | val acc: 0.7515 | val IoU: 0.5418 | val overall: 0.6466
# Epoch 17/20 | train loss: 0.1851 | val loss: 0.8234 | val acc: 0.7620 | val IoU: 0.4996 | val overall: 0.6308
# Epoch 18/20 | train loss: 0.1729 | val loss: 0.8691 | val acc: 0.7567 | val IoU: 0.5328 | val overall: 0.6447
# Epoch 19/20 | train loss: 0.1546 | val loss: 0.8927 | val acc: 0.7467 | val IoU: 0.5299 | val overall: 0.6383
# Epoch 20/20 | train loss: 0.1527 | val loss: 0.9050 | val acc: 0.7588 | val IoU: 0.5374 | val overall: 0.6481
# Best val overall for trial_02_small_lr1e-03_wd1e-04_e20: 0.6481 | trial time: 75.9s (1.26 min)
#
# [3/12] trial_03_small_lr5e-04_wd0e+00_e20 | channels=(16, 32) hidden=128 dropout=0.1
# Epoch 01/20 | train loss: 2.1860 | val loss: 1.9164 | val acc: 0.2340 | val IoU: 0.4390 | val overall: 0.3365
# Epoch 02/20 | train loss: 1.8095 | val loss: 1.7338 | val acc: 0.3225 | val IoU: 0.4766 | val overall: 0.3995
# Epoch 03/20 | train loss: 1.6107 | val loss: 1.5769 | val acc: 0.4035 | val IoU: 0.4939 | val overall: 0.4487
# Epoch 04/20 | train loss: 1.4377 | val loss: 1.3929 | val acc: 0.4748 | val IoU: 0.4958 | val overall: 0.4853
# Epoch 05/20 | train loss: 1.2849 | val loss: 1.2850 | val acc: 0.5225 | val IoU: 0.4806 | val overall: 0.5015
# Epoch 06/20 | train loss: 1.1460 | val loss: 1.1718 | val acc: 0.5708 | val IoU: 0.4821 | val overall: 0.5265
# Epoch 07/20 | train loss: 1.0212 | val loss: 1.0462 | val acc: 0.6225 | val IoU: 0.4582 | val overall: 0.5404
# Epoch 08/20 | train loss: 0.9134 | val loss: 0.9833 | val acc: 0.6433 | val IoU: 0.4770 | val overall: 0.5602
# Epoch 09/20 | train loss: 0.8152 | val loss: 0.9227 | val acc: 0.6697 | val IoU: 0.4772 | val overall: 0.5735
# Epoch 10/20 | train loss: 0.7306 | val loss: 0.8906 | val acc: 0.6853 | val IoU: 0.4715 | val overall: 0.5784
# Epoch 11/20 | train loss: 0.6534 | val loss: 0.8978 | val acc: 0.6762 | val IoU: 0.4726 | val overall: 0.5744
# Epoch 12/20 | train loss: 0.5904 | val loss: 0.8531 | val acc: 0.6973 | val IoU: 0.4702 | val overall: 0.5838
# Epoch 13/20 | train loss: 0.5303 | val loss: 0.8437 | val acc: 0.7058 | val IoU: 0.4627 | val overall: 0.5842
# Epoch 14/20 | train loss: 0.4771 | val loss: 0.8383 | val acc: 0.7043 | val IoU: 0.4764 | val overall: 0.5904
# Epoch 15/20 | train loss: 0.4290 | val loss: 0.8688 | val acc: 0.7032 | val IoU: 0.4570 | val overall: 0.5801
# Epoch 16/20 | train loss: 0.3884 | val loss: 0.8959 | val acc: 0.6962 | val IoU: 0.4621 | val overall: 0.5791
# Epoch 17/20 | train loss: 0.3447 | val loss: 0.8981 | val acc: 0.7097 | val IoU: 0.4779 | val overall: 0.5938
# Epoch 18/20 | train loss: 0.3131 | val loss: 0.9280 | val acc: 0.7010 | val IoU: 0.4754 | val overall: 0.5882
# Epoch 19/20 | train loss: 0.2875 | val loss: 0.9410 | val acc: 0.7070 | val IoU: 0.4726 | val overall: 0.5898
# Epoch 20/20 | train loss: 0.2584 | val loss: 0.9636 | val acc: 0.7080 | val IoU: 0.4814 | val overall: 0.5947
# Best val overall for trial_03_small_lr5e-04_wd0e+00_e20: 0.5947 | trial time: 78.5s (1.31 min)
#
# [4/12] trial_04_small_lr5e-04_wd1e-04_e20 | channels=(16, 32) hidden=128 dropout=0.1
# Epoch 01/20 | train loss: 2.0861 | val loss: 1.7586 | val acc: 0.3063 | val IoU: 0.4759 | val overall: 0.3911
# Epoch 02/20 | train loss: 1.6784 | val loss: 1.5677 | val acc: 0.3847 | val IoU: 0.4897 | val overall: 0.4372
# Epoch 03/20 | train loss: 1.4807 | val loss: 1.3911 | val acc: 0.4743 | val IoU: 0.4830 | val overall: 0.4787
# Epoch 04/20 | train loss: 1.3162 | val loss: 1.2648 | val acc: 0.5283 | val IoU: 0.4829 | val overall: 0.5056
# Epoch 05/20 | train loss: 1.1736 | val loss: 1.1665 | val acc: 0.5692 | val IoU: 0.4848 | val overall: 0.5270
# Epoch 06/20 | train loss: 1.0520 | val loss: 1.0708 | val acc: 0.6113 | val IoU: 0.4864 | val overall: 0.5489
# Epoch 07/20 | train loss: 0.9415 | val loss: 1.0349 | val acc: 0.6243 | val IoU: 0.4942 | val overall: 0.5593
# Epoch 08/20 | train loss: 0.8364 | val loss: 0.9665 | val acc: 0.6512 | val IoU: 0.4985 | val overall: 0.5748
# Epoch 09/20 | train loss: 0.7355 | val loss: 0.8793 | val acc: 0.6895 | val IoU: 0.5015 | val overall: 0.5955
# Epoch 10/20 | train loss: 0.6536 | val loss: 0.8702 | val acc: 0.6858 | val IoU: 0.5106 | val overall: 0.5982
# Epoch 11/20 | train loss: 0.5851 | val loss: 0.8251 | val acc: 0.7063 | val IoU: 0.5221 | val overall: 0.6142
# Epoch 12/20 | train loss: 0.5170 | val loss: 0.8231 | val acc: 0.7090 | val IoU: 0.5104 | val overall: 0.6097
# Epoch 13/20 | train loss: 0.4596 | val loss: 0.8282 | val acc: 0.7078 | val IoU: 0.5162 | val overall: 0.6120
# Epoch 14/20 | train loss: 0.4030 | val loss: 0.8019 | val acc: 0.7237 | val IoU: 0.5225 | val overall: 0.6231
# Epoch 15/20 | train loss: 0.3572 | val loss: 0.8096 | val acc: 0.7233 | val IoU: 0.5350 | val overall: 0.6292
# Epoch 16/20 | train loss: 0.3096 | val loss: 0.8281 | val acc: 0.7267 | val IoU: 0.5437 | val overall: 0.6352
# Epoch 17/20 | train loss: 0.2745 | val loss: 0.8385 | val acc: 0.7240 | val IoU: 0.5507 | val overall: 0.6373
# Epoch 18/20 | train loss: 0.2439 | val loss: 0.9264 | val acc: 0.7097 | val IoU: 0.5465 | val overall: 0.6281
# Epoch 19/20 | train loss: 0.2184 | val loss: 0.9018 | val acc: 0.7218 | val IoU: 0.5469 | val overall: 0.6343
# Epoch 20/20 | train loss: 0.1939 | val loss: 0.9226 | val acc: 0.7213 | val IoU: 0.5594 | val overall: 0.6404
# Best val overall for trial_04_small_lr5e-04_wd1e-04_e20: 0.6404 | trial time: 82.4s (1.37 min)
#
# [5/12] trial_05_base_lr1e-03_wd0e+00_e20 | channels=(16, 32, 64) hidden=256 dropout=0.15
# Epoch 01/20 | train loss: 1.7359 | val loss: 1.1848 | val acc: 0.5668 | val IoU: 0.4716 | val overall: 0.5192
# Epoch 02/20 | train loss: 0.8438 | val loss: 0.6190 | val acc: 0.7898 | val IoU: 0.5386 | val overall: 0.6642
# Epoch 03/20 | train loss: 0.5224 | val loss: 0.4426 | val acc: 0.8523 | val IoU: 0.5382 | val overall: 0.6953
# Epoch 04/20 | train loss: 0.3877 | val loss: 0.3714 | val acc: 0.8743 | val IoU: 0.5444 | val overall: 0.7094
# Epoch 05/20 | train loss: 0.3021 | val loss: 0.3191 | val acc: 0.8902 | val IoU: 0.5444 | val overall: 0.7173
# Epoch 06/20 | train loss: 0.2452 | val loss: 0.3072 | val acc: 0.8997 | val IoU: 0.5481 | val overall: 0.7239
# Epoch 07/20 | train loss: 0.1990 | val loss: 0.3091 | val acc: 0.8927 | val IoU: 0.5526 | val overall: 0.7226
# Epoch 08/20 | train loss: 0.1638 | val loss: 0.3213 | val acc: 0.8957 | val IoU: 0.5348 | val overall: 0.7152
# Epoch 09/20 | train loss: 0.1316 | val loss: 0.3514 | val acc: 0.8900 | val IoU: 0.5591 | val overall: 0.7246
# Epoch 10/20 | train loss: 0.1120 | val loss: 0.3277 | val acc: 0.9055 | val IoU: 0.5559 | val overall: 0.7307
# Epoch 11/20 | train loss: 0.0876 | val loss: 0.3659 | val acc: 0.8982 | val IoU: 0.5508 | val overall: 0.7245
# Epoch 12/20 | train loss: 0.0766 | val loss: 0.3563 | val acc: 0.8997 | val IoU: 0.5524 | val overall: 0.7260
# Epoch 13/20 | train loss: 0.0639 | val loss: 0.3904 | val acc: 0.9027 | val IoU: 0.5528 | val overall: 0.7278
# Epoch 14/20 | train loss: 0.0525 | val loss: 0.4013 | val acc: 0.9052 | val IoU: 0.5477 | val overall: 0.7264
# Epoch 15/20 | train loss: 0.0501 | val loss: 0.4465 | val acc: 0.8943 | val IoU: 0.5559 | val overall: 0.7251
# Epoch 16/20 | train loss: 0.0460 | val loss: 0.4629 | val acc: 0.9033 | val IoU: 0.5464 | val overall: 0.7249
# Epoch 17/20 | train loss: 0.0451 | val loss: 0.4516 | val acc: 0.8978 | val IoU: 0.5582 | val overall: 0.7280
# Epoch 18/20 | train loss: 0.0440 | val loss: 0.4638 | val acc: 0.9020 | val IoU: 0.5525 | val overall: 0.7273
# Epoch 19/20 | train loss: 0.0341 | val loss: 0.4441 | val acc: 0.9078 | val IoU: 0.5475 | val overall: 0.7277
# Epoch 20/20 | train loss: 0.0355 | val loss: 0.4823 | val acc: 0.9043 | val IoU: 0.5563 | val overall: 0.7303
# Best val overall for trial_05_base_lr1e-03_wd0e+00_e20: 0.7307 | trial time: 85.3s (1.42 min)
#
# [6/12] trial_06_base_lr1e-03_wd1e-04_e20 | channels=(16, 32, 64) hidden=256 dropout=0.15
# Epoch 01/20 | train loss: 1.8533 | val loss: 1.2574 | val acc: 0.5223 | val IoU: 0.5005 | val overall: 0.5114
# Epoch 02/20 | train loss: 0.9589 | val loss: 0.6936 | val acc: 0.7565 | val IoU: 0.5208 | val overall: 0.6386
# Epoch 03/20 | train loss: 0.5903 | val loss: 0.4950 | val acc: 0.8283 | val IoU: 0.5197 | val overall: 0.6740
# Epoch 04/20 | train loss: 0.4423 | val loss: 0.4412 | val acc: 0.8448 | val IoU: 0.5276 | val overall: 0.6862
# Epoch 05/20 | train loss: 0.3516 | val loss: 0.4094 | val acc: 0.8592 | val IoU: 0.5516 | val overall: 0.7054
# Epoch 06/20 | train loss: 0.2935 | val loss: 0.3351 | val acc: 0.8863 | val IoU: 0.5639 | val overall: 0.7251
# Epoch 07/20 | train loss: 0.2405 | val loss: 0.3237 | val acc: 0.8915 | val IoU: 0.5707 | val overall: 0.7311
# Epoch 08/20 | train loss: 0.2067 | val loss: 0.3397 | val acc: 0.8888 | val IoU: 0.5670 | val overall: 0.7279
# Epoch 09/20 | train loss: 0.1757 | val loss: 0.3183 | val acc: 0.8988 | val IoU: 0.5934 | val overall: 0.7461
# Epoch 10/20 | train loss: 0.1555 | val loss: 0.3165 | val acc: 0.8998 | val IoU: 0.5825 | val overall: 0.7412
# Epoch 11/20 | train loss: 0.1306 | val loss: 0.3220 | val acc: 0.9018 | val IoU: 0.5636 | val overall: 0.7327
# Epoch 12/20 | train loss: 0.1126 | val loss: 0.3213 | val acc: 0.9010 | val IoU: 0.6055 | val overall: 0.7532
# Epoch 13/20 | train loss: 0.0987 | val loss: 0.3639 | val acc: 0.8887 | val IoU: 0.5846 | val overall: 0.7366
# Epoch 14/20 | train loss: 0.0941 | val loss: 0.3268 | val acc: 0.9037 | val IoU: 0.5992 | val overall: 0.7514
# Epoch 15/20 | train loss: 0.0789 | val loss: 0.3559 | val acc: 0.9040 | val IoU: 0.6095 | val overall: 0.7568
# Epoch 16/20 | train loss: 0.0736 | val loss: 0.3617 | val acc: 0.9003 | val IoU: 0.6145 | val overall: 0.7574
# Epoch 17/20 | train loss: 0.0654 | val loss: 0.3911 | val acc: 0.8985 | val IoU: 0.6147 | val overall: 0.7566
# Epoch 18/20 | train loss: 0.0655 | val loss: 0.3759 | val acc: 0.8942 | val IoU: 0.6106 | val overall: 0.7524
# Epoch 19/20 | train loss: 0.0636 | val loss: 0.3806 | val acc: 0.8992 | val IoU: 0.6264 | val overall: 0.7628
# Epoch 20/20 | train loss: 0.0544 | val loss: 0.4149 | val acc: 0.9015 | val IoU: 0.6174 | val overall: 0.7595
# Best val overall for trial_06_base_lr1e-03_wd1e-04_e20: 0.7628 | trial time: 86.0s (1.43 min)
#
# [7/12] trial_07_base_lr5e-04_wd0e+00_e20 | channels=(16, 32, 64) hidden=256 dropout=0.15
# Epoch 01/20 | train loss: 2.0188 | val loss: 1.7347 | val acc: 0.3212 | val IoU: 0.5054 | val overall: 0.4133
# Epoch 02/20 | train loss: 1.3978 | val loss: 1.0542 | val acc: 0.6235 | val IoU: 0.5185 | val overall: 0.5710
# Epoch 03/20 | train loss: 0.8960 | val loss: 0.7613 | val acc: 0.7333 | val IoU: 0.5093 | val overall: 0.6213
# Epoch 04/20 | train loss: 0.6573 | val loss: 0.5741 | val acc: 0.8003 | val IoU: 0.5450 | val overall: 0.6727
# Epoch 05/20 | train loss: 0.5174 | val loss: 0.4725 | val acc: 0.8415 | val IoU: 0.5329 | val overall: 0.6872
# Epoch 06/20 | train loss: 0.4267 | val loss: 0.4576 | val acc: 0.8392 | val IoU: 0.5301 | val overall: 0.6846
# Epoch 07/20 | train loss: 0.3648 | val loss: 0.4146 | val acc: 0.8547 | val IoU: 0.5175 | val overall: 0.6861
# Epoch 08/20 | train loss: 0.3094 | val loss: 0.3634 | val acc: 0.8733 | val IoU: 0.5535 | val overall: 0.7134
# Epoch 09/20 | train loss: 0.2674 | val loss: 0.3583 | val acc: 0.8770 | val IoU: 0.5628 | val overall: 0.7199
# Epoch 10/20 | train loss: 0.2338 | val loss: 0.3364 | val acc: 0.8850 | val IoU: 0.5688 | val overall: 0.7269
# Epoch 11/20 | train loss: 0.2011 | val loss: 0.3383 | val acc: 0.8865 | val IoU: 0.5607 | val overall: 0.7236
# Epoch 12/20 | train loss: 0.1741 | val loss: 0.3274 | val acc: 0.8932 | val IoU: 0.5722 | val overall: 0.7327
# Epoch 13/20 | train loss: 0.1463 | val loss: 0.3338 | val acc: 0.8937 | val IoU: 0.5794 | val overall: 0.7366
# Epoch 14/20 | train loss: 0.1244 | val loss: 0.3406 | val acc: 0.8907 | val IoU: 0.5710 | val overall: 0.7309
# Epoch 15/20 | train loss: 0.1039 | val loss: 0.3541 | val acc: 0.8937 | val IoU: 0.5681 | val overall: 0.7309
# Epoch 16/20 | train loss: 0.0913 | val loss: 0.3567 | val acc: 0.8928 | val IoU: 0.5770 | val overall: 0.7349
# Epoch 17/20 | train loss: 0.0775 | val loss: 0.3924 | val acc: 0.8878 | val IoU: 0.5756 | val overall: 0.7317
# Epoch 18/20 | train loss: 0.0684 | val loss: 0.4258 | val acc: 0.8868 | val IoU: 0.5752 | val overall: 0.7310
# Epoch 19/20 | train loss: 0.0624 | val loss: 0.4078 | val acc: 0.8932 | val IoU: 0.5746 | val overall: 0.7339
# Epoch 20/20 | train loss: 0.0507 | val loss: 0.4268 | val acc: 0.8920 | val IoU: 0.5777 | val overall: 0.7349
# Best val overall for trial_07_base_lr5e-04_wd0e+00_e20: 0.7366 | trial time: 82.6s (1.38 min)
#
# [8/12] trial_08_base_lr5e-04_wd1e-04_e20 | channels=(16, 32, 64) hidden=256 dropout=0.15
# Epoch 01/20 | train loss: 2.0832 | val loss: 1.6766 | val acc: 0.3622 | val IoU: 0.4812 | val overall: 0.4217
# Epoch 02/20 | train loss: 1.4534 | val loss: 1.1822 | val acc: 0.5820 | val IoU: 0.5023 | val overall: 0.5422
# Epoch 03/20 | train loss: 1.0049 | val loss: 0.8487 | val acc: 0.6933 | val IoU: 0.5315 | val overall: 0.6124
# Epoch 04/20 | train loss: 0.7367 | val loss: 0.6288 | val acc: 0.7777 | val IoU: 0.5291 | val overall: 0.6534
# Epoch 05/20 | train loss: 0.5789 | val loss: 0.5229 | val acc: 0.8123 | val IoU: 0.5553 | val overall: 0.6838
# Epoch 06/20 | train loss: 0.4760 | val loss: 0.4662 | val acc: 0.8357 | val IoU: 0.5503 | val overall: 0.6930
# Epoch 07/20 | train loss: 0.4029 | val loss: 0.4304 | val acc: 0.8445 | val IoU: 0.5844 | val overall: 0.7145
# Epoch 08/20 | train loss: 0.3491 | val loss: 0.4402 | val acc: 0.8463 | val IoU: 0.5735 | val overall: 0.7099
# Epoch 09/20 | train loss: 0.3045 | val loss: 0.3787 | val acc: 0.8637 | val IoU: 0.5922 | val overall: 0.7280
# Epoch 10/20 | train loss: 0.2657 | val loss: 0.3418 | val acc: 0.8772 | val IoU: 0.6035 | val overall: 0.7404
# Epoch 11/20 | train loss: 0.2357 | val loss: 0.3408 | val acc: 0.8783 | val IoU: 0.6042 | val overall: 0.7413
# Epoch 12/20 | train loss: 0.2038 | val loss: 0.3194 | val acc: 0.8835 | val IoU: 0.6010 | val overall: 0.7422
# Epoch 13/20 | train loss: 0.1836 | val loss: 0.3365 | val acc: 0.8840 | val IoU: 0.6076 | val overall: 0.7458
# Epoch 14/20 | train loss: 0.1570 | val loss: 0.3477 | val acc: 0.8827 | val IoU: 0.6186 | val overall: 0.7507
# Epoch 15/20 | train loss: 0.1371 | val loss: 0.3496 | val acc: 0.8852 | val IoU: 0.6177 | val overall: 0.7515
# Epoch 16/20 | train loss: 0.1188 | val loss: 0.3538 | val acc: 0.8855 | val IoU: 0.6175 | val overall: 0.7515
# Epoch 17/20 | train loss: 0.1022 | val loss: 0.3615 | val acc: 0.8912 | val IoU: 0.6251 | val overall: 0.7581
# Epoch 18/20 | train loss: 0.0926 | val loss: 0.3657 | val acc: 0.8898 | val IoU: 0.6205 | val overall: 0.7552
# Epoch 19/20 | train loss: 0.0804 | val loss: 0.3770 | val acc: 0.8902 | val IoU: 0.6461 | val overall: 0.7681
# Epoch 20/20 | train loss: 0.0749 | val loss: 0.4445 | val acc: 0.8717 | val IoU: 0.6269 | val overall: 0.7493
# Best val overall for trial_08_base_lr5e-04_wd1e-04_e20: 0.7681 | trial time: 86.1s (1.44 min)
#
# [9/12] trial_09_deep_lr1e-03_wd0e+00_e20 | channels=(16, 32, 64, 96) hidden=256 dropout=0.2
# Epoch 01/20 | train loss: 1.7658 | val loss: 0.9341 | val acc: 0.6503 | val IoU: 0.5215 | val overall: 0.5859
# Epoch 02/20 | train loss: 0.7049 | val loss: 0.4847 | val acc: 0.8347 | val IoU: 0.5152 | val overall: 0.6749
# Epoch 03/20 | train loss: 0.4165 | val loss: 0.3538 | val acc: 0.8775 | val IoU: 0.5215 | val overall: 0.6995
# Epoch 04/20 | train loss: 0.3041 | val loss: 0.3031 | val acc: 0.8953 | val IoU: 0.5453 | val overall: 0.7203
# Epoch 05/20 | train loss: 0.2481 | val loss: 0.2695 | val acc: 0.9058 | val IoU: 0.5647 | val overall: 0.7352
# Epoch 06/20 | train loss: 0.2026 | val loss: 0.2330 | val acc: 0.9205 | val IoU: 0.5721 | val overall: 0.7463
# Epoch 07/20 | train loss: 0.1734 | val loss: 0.2360 | val acc: 0.9232 | val IoU: 0.5774 | val overall: 0.7503
# Epoch 08/20 | train loss: 0.1459 | val loss: 0.2288 | val acc: 0.9248 | val IoU: 0.5699 | val overall: 0.7474
# Epoch 09/20 | train loss: 0.1254 | val loss: 0.2358 | val acc: 0.9258 | val IoU: 0.5603 | val overall: 0.7431
# Epoch 10/20 | train loss: 0.1132 | val loss: 0.2217 | val acc: 0.9287 | val IoU: 0.5653 | val overall: 0.7470
# Epoch 11/20 | train loss: 0.0905 | val loss: 0.2212 | val acc: 0.9288 | val IoU: 0.5672 | val overall: 0.7480
# Epoch 12/20 | train loss: 0.0813 | val loss: 0.2384 | val acc: 0.9293 | val IoU: 0.5700 | val overall: 0.7497
# Epoch 13/20 | train loss: 0.0703 | val loss: 0.2375 | val acc: 0.9267 | val IoU: 0.5508 | val overall: 0.7387
# Epoch 14/20 | train loss: 0.0686 | val loss: 0.2408 | val acc: 0.9280 | val IoU: 0.5607 | val overall: 0.7443
# Epoch 15/20 | train loss: 0.0560 | val loss: 0.2799 | val acc: 0.9272 | val IoU: 0.5654 | val overall: 0.7463
# Epoch 16/20 | train loss: 0.0556 | val loss: 0.2948 | val acc: 0.9287 | val IoU: 0.5512 | val overall: 0.7399
# Epoch 17/20 | train loss: 0.0488 | val loss: 0.3393 | val acc: 0.9205 | val IoU: 0.5612 | val overall: 0.7409
# Epoch 18/20 | train loss: 0.0450 | val loss: 0.2866 | val acc: 0.9315 | val IoU: 0.5684 | val overall: 0.7499
# Epoch 19/20 | train loss: 0.0394 | val loss: 0.3269 | val acc: 0.9268 | val IoU: 0.5564 | val overall: 0.7416
# Epoch 20/20 | train loss: 0.0365 | val loss: 0.3094 | val acc: 0.9345 | val IoU: 0.5817 | val overall: 0.7581
# Best val overall for trial_09_deep_lr1e-03_wd0e+00_e20: 0.7581 | trial time: 87.1s (1.45 min)
#
# [10/12] trial_10_deep_lr1e-03_wd1e-04_e20 | channels=(16, 32, 64, 96) hidden=256 dropout=0.2
# Epoch 01/20 | train loss: 1.6579 | val loss: 0.8710 | val acc: 0.6878 | val IoU: 0.4845 | val overall: 0.5862
# Epoch 02/20 | train loss: 0.5841 | val loss: 0.4461 | val acc: 0.8437 | val IoU: 0.5072 | val overall: 0.6754
# Epoch 03/20 | train loss: 0.3605 | val loss: 0.3150 | val acc: 0.8912 | val IoU: 0.5573 | val overall: 0.7242
# Epoch 04/20 | train loss: 0.2735 | val loss: 0.2867 | val acc: 0.9002 | val IoU: 0.5700 | val overall: 0.7351
# Epoch 05/20 | train loss: 0.2226 | val loss: 0.2618 | val acc: 0.9125 | val IoU: 0.5515 | val overall: 0.7320
# Epoch 06/20 | train loss: 0.1852 | val loss: 0.2341 | val acc: 0.9208 | val IoU: 0.5699 | val overall: 0.7454
# Epoch 07/20 | train loss: 0.1613 | val loss: 0.2301 | val acc: 0.9213 | val IoU: 0.5782 | val overall: 0.7498
# Epoch 08/20 | train loss: 0.1441 | val loss: 0.2733 | val acc: 0.9113 | val IoU: 0.5829 | val overall: 0.7471
# Epoch 09/20 | train loss: 0.1254 | val loss: 0.2275 | val acc: 0.9258 | val IoU: 0.5771 | val overall: 0.7514
# Epoch 10/20 | train loss: 0.1085 | val loss: 0.2206 | val acc: 0.9322 | val IoU: 0.5928 | val overall: 0.7625
# Epoch 11/20 | train loss: 0.1005 | val loss: 0.2144 | val acc: 0.9355 | val IoU: 0.5981 | val overall: 0.7668
# Epoch 12/20 | train loss: 0.0823 | val loss: 0.2130 | val acc: 0.9378 | val IoU: 0.5871 | val overall: 0.7624
# Epoch 13/20 | train loss: 0.0764 | val loss: 0.2367 | val acc: 0.9325 | val IoU: 0.5964 | val overall: 0.7644
# Epoch 14/20 | train loss: 0.0715 | val loss: 0.2711 | val acc: 0.9288 | val IoU: 0.5913 | val overall: 0.7601
# Epoch 15/20 | train loss: 0.0655 | val loss: 0.2668 | val acc: 0.9285 | val IoU: 0.5914 | val overall: 0.7599
# Epoch 16/20 | train loss: 0.0562 | val loss: 0.2483 | val acc: 0.9370 | val IoU: 0.5946 | val overall: 0.7658
# Epoch 17/20 | train loss: 0.0553 | val loss: 0.2860 | val acc: 0.9242 | val IoU: 0.6149 | val overall: 0.7695
# Epoch 18/20 | train loss: 0.0502 | val loss: 0.2538 | val acc: 0.9383 | val IoU: 0.5957 | val overall: 0.7670
# Epoch 19/20 | train loss: 0.0464 | val loss: 0.2495 | val acc: 0.9370 | val IoU: 0.6124 | val overall: 0.7747
# Epoch 20/20 | train loss: 0.0410 | val loss: 0.2638 | val acc: 0.9365 | val IoU: 0.6242 | val overall: 0.7803
# Best val overall for trial_10_deep_lr1e-03_wd1e-04_e20: 0.7803 | trial time: 88.2s (1.47 min)
#
# [11/12] trial_11_deep_lr5e-04_wd0e+00_e20 | channels=(16, 32, 64, 96) hidden=256 dropout=0.2
# Epoch 01/20 | train loss: 1.9712 | val loss: 1.4999 | val acc: 0.4135 | val IoU: 0.4798 | val overall: 0.4467
# Epoch 02/20 | train loss: 1.1145 | val loss: 0.8007 | val acc: 0.7060 | val IoU: 0.5138 | val overall: 0.6099
# Epoch 03/20 | train loss: 0.6663 | val loss: 0.5379 | val acc: 0.8092 | val IoU: 0.5228 | val overall: 0.6660
# Epoch 04/20 | train loss: 0.4951 | val loss: 0.4627 | val acc: 0.8405 | val IoU: 0.5374 | val overall: 0.6890
# Epoch 05/20 | train loss: 0.3999 | val loss: 0.3896 | val acc: 0.8625 | val IoU: 0.5396 | val overall: 0.7011
# Epoch 06/20 | train loss: 0.3349 | val loss: 0.3390 | val acc: 0.8825 | val IoU: 0.5538 | val overall: 0.7182
# Epoch 07/20 | train loss: 0.2818 | val loss: 0.3034 | val acc: 0.8962 | val IoU: 0.5654 | val overall: 0.7308
# Epoch 08/20 | train loss: 0.2475 | val loss: 0.2864 | val acc: 0.9027 | val IoU: 0.5715 | val overall: 0.7371
# Epoch 09/20 | train loss: 0.2166 | val loss: 0.3185 | val acc: 0.8895 | val IoU: 0.5770 | val overall: 0.7333
# Epoch 10/20 | train loss: 0.1981 | val loss: 0.2549 | val acc: 0.9137 | val IoU: 0.5880 | val overall: 0.7508
# Epoch 11/20 | train loss: 0.1734 | val loss: 0.2459 | val acc: 0.9183 | val IoU: 0.5822 | val overall: 0.7503
# Epoch 12/20 | train loss: 0.1525 | val loss: 0.2340 | val acc: 0.9230 | val IoU: 0.5921 | val overall: 0.7576
# Epoch 13/20 | train loss: 0.1378 | val loss: 0.2332 | val acc: 0.9238 | val IoU: 0.5880 | val overall: 0.7559
# Epoch 14/20 | train loss: 0.1187 | val loss: 0.2573 | val acc: 0.9223 | val IoU: 0.5923 | val overall: 0.7573
# Epoch 15/20 | train loss: 0.1051 | val loss: 0.2469 | val acc: 0.9217 | val IoU: 0.5762 | val overall: 0.7489
# Epoch 16/20 | train loss: 0.0937 | val loss: 0.2550 | val acc: 0.9230 | val IoU: 0.5991 | val overall: 0.7610
# Epoch 17/20 | train loss: 0.0807 | val loss: 0.2568 | val acc: 0.9245 | val IoU: 0.5867 | val overall: 0.7556
# Epoch 18/20 | train loss: 0.0706 | val loss: 0.2867 | val acc: 0.9223 | val IoU: 0.5923 | val overall: 0.7573
# Epoch 19/20 | train loss: 0.0665 | val loss: 0.2914 | val acc: 0.9245 | val IoU: 0.6028 | val overall: 0.7636
# Epoch 20/20 | train loss: 0.0567 | val loss: 0.2831 | val acc: 0.9253 | val IoU: 0.5904 | val overall: 0.7579
# Best val overall for trial_11_deep_lr5e-04_wd0e+00_e20: 0.7636 | trial time: 93.8s (1.56 min)
#
# [12/12] trial_12_deep_lr5e-04_wd1e-04_e20 | channels=(16, 32, 64, 96) hidden=256 dropout=0.2
# Epoch 01/20 | train loss: 2.0207 | val loss: 1.9190 | val acc: 0.2800 | val IoU: 0.4948 | val overall: 0.3874
# Epoch 02/20 | train loss: 1.1066 | val loss: 0.7416 | val acc: 0.7368 | val IoU: 0.5180 | val overall: 0.6274
# Epoch 03/20 | train loss: 0.6375 | val loss: 0.5686 | val acc: 0.8002 | val IoU: 0.5240 | val overall: 0.6621
# Epoch 04/20 | train loss: 0.4622 | val loss: 0.4409 | val acc: 0.8502 | val IoU: 0.5699 | val overall: 0.7100
# Epoch 05/20 | train loss: 0.3731 | val loss: 0.3447 | val acc: 0.8832 | val IoU: 0.5888 | val overall: 0.7360
# Epoch 06/20 | train loss: 0.3105 | val loss: 0.3718 | val acc: 0.8710 | val IoU: 0.5996 | val overall: 0.7353
# Epoch 07/20 | train loss: 0.2673 | val loss: 0.2823 | val acc: 0.8990 | val IoU: 0.6007 | val overall: 0.7499
# Epoch 08/20 | train loss: 0.2299 | val loss: 0.2840 | val acc: 0.9038 | val IoU: 0.6015 | val overall: 0.7526
# Epoch 09/20 | train loss: 0.2060 | val loss: 0.2667 | val acc: 0.9067 | val IoU: 0.5868 | val overall: 0.7467
# Epoch 10/20 | train loss: 0.1841 | val loss: 0.2465 | val acc: 0.9173 | val IoU: 0.5986 | val overall: 0.7580
# Epoch 11/20 | train loss: 0.1596 | val loss: 0.2355 | val acc: 0.9223 | val IoU: 0.6280 | val overall: 0.7751
# Epoch 12/20 | train loss: 0.1442 | val loss: 0.2194 | val acc: 0.9280 | val IoU: 0.6304 | val overall: 0.7792
# Epoch 13/20 | train loss: 0.1252 | val loss: 0.2329 | val acc: 0.9268 | val IoU: 0.6206 | val overall: 0.7737
# Epoch 14/20 | train loss: 0.1161 | val loss: 0.2472 | val acc: 0.9227 | val IoU: 0.6312 | val overall: 0.7769
# Epoch 15/20 | train loss: 0.1013 | val loss: 0.2356 | val acc: 0.9265 | val IoU: 0.6282 | val overall: 0.7773
# Epoch 16/20 | train loss: 0.0889 | val loss: 0.2195 | val acc: 0.9298 | val IoU: 0.6337 | val overall: 0.7818
# Epoch 17/20 | train loss: 0.0799 | val loss: 0.2360 | val acc: 0.9233 | val IoU: 0.6508 | val overall: 0.7871
# Epoch 18/20 | train loss: 0.0712 | val loss: 0.2477 | val acc: 0.9283 | val IoU: 0.6411 | val overall: 0.7847
# Epoch 19/20 | train loss: 0.0662 | val loss: 0.2334 | val acc: 0.9308 | val IoU: 0.6533 | val overall: 0.7921
# Epoch 20/20 | train loss: 0.0563 | val loss: 0.2777 | val acc: 0.9257 | val IoU: 0.6587 | val overall: 0.7922
# Best val overall for trial_12_deep_lr5e-04_wd1e-04_e20: 0.7922 | trial time: 89.8s (1.50 min)
#
# Total tuning/training time: 1007.7s (16.79 min)
#
# Hyperparameter tuning summary (sorted by best val overall):
#    trial_12_deep_lr5e-04_wd1e-04_e20 | best val overall: 0.7922 | time: 89.8s
#    trial_10_deep_lr1e-03_wd1e-04_e20 | best val overall: 0.7803 | time: 88.2s
#    trial_08_base_lr5e-04_wd1e-04_e20 | best val overall: 0.7681 | time: 86.1s
#    trial_11_deep_lr5e-04_wd0e+00_e20 | best val overall: 0.7636 | time: 93.8s
#    trial_06_base_lr1e-03_wd1e-04_e20 | best val overall: 0.7628 | time: 86.0s
#    trial_09_deep_lr1e-03_wd0e+00_e20 | best val overall: 0.7581 | time: 87.1s
#    trial_07_base_lr5e-04_wd0e+00_e20 | best val overall: 0.7366 | time: 82.6s
#    trial_05_base_lr1e-03_wd0e+00_e20 | best val overall: 0.7307 | time: 85.3s
#   trial_02_small_lr1e-03_wd1e-04_e20 | best val overall: 0.6481 | time: 75.9s
#   trial_04_small_lr5e-04_wd1e-04_e20 | best val overall: 0.6404 | time: 82.4s
#   trial_03_small_lr5e-04_wd0e+00_e20 | best val overall: 0.5947 | time: 78.5s
#   trial_01_small_lr1e-03_wd0e+00_e20 | best val overall: 0.5910 | time: 72.0s
#
# Selected best tuning trial: trial_12_deep_lr5e-04_wd1e-04_e20

# %% [markdown]
# ### Predictions

# %%
def _bbox_center_to_rect(bb, image_height=IMAGE_HEIGHT, image_width=IMAGE_WIDTH):
    x, y, w, h = bb.tolist()
    left = (x - 0.5 * w) * image_width
    top = (y - 0.5 * h) * image_height
    width = w * image_width
    height = h * image_height
    return left, top, width, height


plot_model = globals().get('best_model')
if plot_model is None:
    plot_model = globals().get('model')
if plot_model is None:
    raise RuntimeError('No trained model found. Run the training/model-selection cells first.')

plot_model.eval()

splits = [
    ('Train', train_data),
    ('Validation', val_data),
    ('Test', test_data),
]

samples_per_split = 4
fig, axes = plt.subplots(len(splits), samples_per_split, figsize=(4 * samples_per_split, 3.6 * len(splits)))

if len(splits) == 1:
    axes = [axes]

with torch.no_grad():
    for row, (split_name, dataset) in enumerate(splits):
        indices = torch.randperm(len(dataset))[:samples_per_split]
        for col, idx in enumerate(indices):
            ax = axes[row][col]
            image, target = dataset[int(idx)]
            image = _ensure_channel_first(image)

            model_input = preprocessor(image).unsqueeze(0).to(device)
            pred = plot_model(model_input).cpu().squeeze(0)

            pred_pc = torch.sigmoid(pred[0]).item()
            pred_label = pred[5:].argmax().item()
            pred_bbox = torch.sigmoid(pred[1:5])

            true_pc = int(target[0].item())
            true_label = int(target[5].item())
            true_bbox = target[1:5]

            ax.imshow(image.squeeze(0), cmap='gray')

            if true_pc == 1:
                l, t, w, h = _bbox_center_to_rect(true_bbox)
                ax.add_patch(plt.Rectangle((l, t), w, h, fill=False, edgecolor='lime', linewidth=2))

            if pred_pc > 0.5:
                l, t, w, h = _bbox_center_to_rect(pred_bbox)
                ax.add_patch(plt.Rectangle((l, t), w, h, fill=False, edgecolor='red', linewidth=2))

            ax.set_title(
                f"{split_name} | T:{true_label} P:{pred_label}\npc(T/P): {true_pc}/{pred_pc:.2f}",
                fontsize=9,
            )
            ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model selection and evaluation

# %%
def intersection(bb1, bb2):
    """
    Compute intersection between 2 bb, in global frame of ref
    bb format: [x_center, y_center, width, height]
    """
    bb1 = torch.as_tensor(bb1, dtype=torch.float32)
    bb2 = torch.as_tensor(bb2, dtype=torch.float32)

    bb1_min = bb1[:2] - 0.5 * bb1[2:]
    bb1_max = bb1[:2] + 0.5 * bb1[2:]
    bb2_min = bb2[:2] - 0.5 * bb2[2:]
    bb2_max = bb2[:2] + 0.5 * bb2[2:]

    inter_min = torch.maximum(bb1_min, bb2_min)
    inter_max = torch.minimum(bb1_max, bb2_max)
    inter_wh = (inter_max - inter_min).clamp(min=0)
    return (inter_wh[0] * inter_wh[1]).item()


def IoU(bb1, bb2):
    """
    Compute IoU given 2 bb (local or global)
    """
    bb1 = torch.as_tensor(bb1, dtype=torch.float32)
    bb2 = torch.as_tensor(bb2, dtype=torch.float32)

    inter = intersection(bb1, bb2)
    area1 = (bb1[2] * bb1[3]).item()
    area2 = (bb2[2] * bb2[3]).item()
    union = area1 + area2 - inter
    if union <= 0:
        return 0.0
    return inter / union


def compute_IoU_localization(model, loader, preprocessor):
    """
    Compute IoU performance of the model on the given dataset
    """
    model.eval()
    total_iou = 0.0
    total_objects = 0

    with torch.no_grad():
        for images, targets in loader:
            if preprocessor is not None:
                images = preprocessor(images)

            images = images.to(device)
            targets = targets.to(device)
            preds = model(images)

            true_obj = targets[:, 0] > 0.5
            if not true_obj.any():
                continue

            pred_obj = torch.sigmoid(preds[:, 0]) > 0.5
            pred_bbox = torch.sigmoid(preds[:, 1:5])
            true_bbox = targets[:, 1:5]

            pred_bbox = pred_bbox[true_obj]
            true_bbox = true_bbox[true_obj]
            detected = pred_obj[true_obj]

            pred_min = pred_bbox[:, :2] - 0.5 * pred_bbox[:, 2:]
            pred_max = pred_bbox[:, :2] + 0.5 * pred_bbox[:, 2:]
            true_min = true_bbox[:, :2] - 0.5 * true_bbox[:, 2:]
            true_max = true_bbox[:, :2] + 0.5 * true_bbox[:, 2:]

            inter_min = torch.maximum(pred_min, true_min)
            inter_max = torch.minimum(pred_max, true_max)
            inter_wh = (inter_max - inter_min).clamp(min=0)
            inter_area = inter_wh[:, 0] * inter_wh[:, 1]

            pred_area = (pred_bbox[:, 2] * pred_bbox[:, 3]).clamp(min=0)
            true_area = (true_bbox[:, 2] * true_bbox[:, 3]).clamp(min=0)
            union_area = pred_area + true_area - inter_area

            iou = torch.where(union_area > 0, inter_area / union_area, torch.zeros_like(union_area))
            iou = iou * detected.float()

            total_iou += iou.sum().item()
            total_objects += true_obj.sum().item()

    if total_objects == 0:
        return 0.0
    return total_iou / total_objects


def compute_accuracy_localization(model, loader, preprocessor):
    """
    Compute accuracy of the model on the given dataset
    """
    model.eval()
    total_objects = 0
    correct = 0

    with torch.no_grad():
        for images, targets in loader:
            if preprocessor is not None:
                images = preprocessor(images)

            images = images.to(device)
            targets = targets.to(device)
            preds = model(images)

            true_obj = targets[:, 0] > 0.5
            if not true_obj.any():
                continue

            pred_obj = torch.sigmoid(preds[:, 0]) > 0.5
            pred_cls = preds[:, 5:].argmax(dim=1)
            true_cls = targets[:, 5].long()

            batch_correct = pred_obj & (pred_cls == true_cls) & true_obj
            correct += batch_correct.sum().item()
            total_objects += true_obj.sum().item()

    if total_objects == 0:
        return 0.0
    return correct / total_objects


# Model selection based on validation overall performance
if 'trained_models' not in globals() or len(trained_models) == 0:
    trained_models = {'single_model': model}

validation_results = {}
for model_name, current_model in trained_models.items():
    val_acc = compute_accuracy_localization(current_model, val_loader, preprocessor=None)
    val_iou = compute_IoU_localization(current_model, val_loader, preprocessor=None)
    val_overall = 0.5 * (val_acc + val_iou)
    validation_results[model_name] = {
        'accuracy': val_acc,
        'iou': val_iou,
        'overall': val_overall,
    }

print('Validation results per model:')
for model_name, metrics in validation_results.items():
    print(
        f"{model_name:>8s} | "
        f"accuracy: {metrics['accuracy']:.4f} | "
        f"IoU: {metrics['iou']:.4f} | "
        f"overall: {metrics['overall']:.4f}"
    )

best_model_name = max(validation_results, key=lambda n: validation_results[n]['overall'])
best_model = trained_models[best_model_name]
model = best_model  # keep a common reference for downstream cells

print(f"\nSelected best model: {best_model_name}")

# Evaluate the best model on test data
test_acc = compute_accuracy_localization(best_model, test_loader, preprocessor=None)
test_iou = compute_IoU_localization(best_model, test_loader, preprocessor=None)
test_overall = 0.5 * (test_acc + test_iou)

print(f"Test accuracy: {test_acc:.4f}")
print(f"Test IoU:      {test_iou:.4f}")
print(f"Test overall:  {test_overall:.4f}")
# Out:
# Validation results per model:
# trial_01_small_lr1e-03_wd0e+00_e20 | accuracy: 0.7317 | IoU: 0.4503 | overall: 0.5910
# trial_02_small_lr1e-03_wd1e-04_e20 | accuracy: 0.7588 | IoU: 0.5374 | overall: 0.6481
# trial_03_small_lr5e-04_wd0e+00_e20 | accuracy: 0.7080 | IoU: 0.4814 | overall: 0.5947
# trial_04_small_lr5e-04_wd1e-04_e20 | accuracy: 0.7213 | IoU: 0.5594 | overall: 0.6404
# trial_05_base_lr1e-03_wd0e+00_e20 | accuracy: 0.9055 | IoU: 0.5559 | overall: 0.7307
# trial_06_base_lr1e-03_wd1e-04_e20 | accuracy: 0.8992 | IoU: 0.6264 | overall: 0.7628
# trial_07_base_lr5e-04_wd0e+00_e20 | accuracy: 0.8937 | IoU: 0.5794 | overall: 0.7366
# trial_08_base_lr5e-04_wd1e-04_e20 | accuracy: 0.8902 | IoU: 0.6461 | overall: 0.7681
# trial_09_deep_lr1e-03_wd0e+00_e20 | accuracy: 0.9345 | IoU: 0.5817 | overall: 0.7581
# trial_10_deep_lr1e-03_wd1e-04_e20 | accuracy: 0.9365 | IoU: 0.6242 | overall: 0.7803
# trial_11_deep_lr5e-04_wd0e+00_e20 | accuracy: 0.9245 | IoU: 0.6028 | overall: 0.7636
# trial_12_deep_lr5e-04_wd1e-04_e20 | accuracy: 0.9257 | IoU: 0.6587 | overall: 0.7922
#
# Selected best model: trial_12_deep_lr5e-04_wd1e-04_e20
# Test accuracy: 0.9311
# Test IoU:      0.6612
# Test overall:  0.7961

# %% [markdown]
# ### Per-model loss graphs

# %%
def compute_average_localization_loss(model, loader, preprocessor=None):
    model.eval()
    total_loss = 0.0
    total_samples = 0

    with torch.no_grad():
        for images, targets in loader:
            if preprocessor is not None:
                images = preprocessor(images)

            images = images.to(device)
            targets = targets.to(device)
            preds = model(images)

            batch_size = images.size(0)
            total_loss += localization_loss(preds, targets).item() * batch_size
            total_samples += batch_size

    if total_samples == 0:
        return float('nan')
    return total_loss / total_samples


if 'training_histories' not in globals() or len(training_histories) == 0:
    raise RuntimeError('No training histories found. Run the hyperparameter tuning and training cell first.')
if 'trained_models' not in globals() or len(trained_models) == 0:
    raise RuntimeError('No trained models found. Run the hyperparameter tuning and training cell first.')
if 'best_model' not in globals() or best_model is None:
    raise RuntimeError('No preselected best model found. Run the earlier model-selection cell first.')
if 'best_model_name' not in globals() or best_model_name is None:
    raise RuntimeError('No preselected best model name found. Run the earlier model-selection cell first.')

loss_histories = {
    model_name: {
        'train_loss': list(history.get('train_loss', [])),
        'val_loss': list(history.get('val_loss', [])),
    }
    for model_name, history in training_histories.items()
}

if len(loss_histories) != 12:
    raise RuntimeError(f'Expected 12 trained models, found {len(loss_histories)}.')
if best_model_name not in loss_histories:
    raise KeyError(f'Best model {best_model_name} is missing from training_histories.')

ordered_model_names = sorted(loss_histories.keys())
print(f'Creating {len(ordered_model_names)} per-model loss graphs.')

for model_name in ordered_model_names:
    history = loss_histories[model_name]
    train_losses = history['train_loss']
    val_losses = history['val_loss']
    if len(train_losses) == 0 or len(val_losses) == 0:
        raise RuntimeError(f'Model {model_name} is missing train_loss or val_loss values.')

    epochs = list(range(1, len(train_losses) + 1))
    fig, ax = plt.subplots(figsize=(8, 4.5))
    ax.plot(epochs, train_losses, marker='o', linewidth=2, label='Training Loss', color='#4C78A8')
    ax.plot(epochs, val_losses, marker='s', linewidth=2, label='Validation Loss', color='#F58518')
    ax.set_title(f'Training and Validation Loss per Epoch for {model_name}')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.set_xticks(epochs)
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
# Creating 12 per-model loss graphs.
